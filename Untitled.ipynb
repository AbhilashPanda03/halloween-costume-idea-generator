# %%
import csv
from utils import *

# %%
data=open('combined.txt','r',encoding='utf8').read()
data=data.lower()
chars=list(set(data))
data_size,vocab_size=len(data),len(chars)
print('There are %d total characters and %d unique characters in your data.' % (data_size, vocab_size))
# Out:
# There are 75971 total characters and 39 unique characters in your data.

# %%
char_to_ix={ch:i for i,ch in enumerate(sorted(chars))}
ix_to_char={i:ch for i,ch in enumerate(sorted(chars))}
print(ix_to_char)
# Out:
# {0: '\n', 1: ' ', 2: '.', 3: '0', 4: '1', 5: '2', 6: '3', 7: '4', 8: '5', 9: '6', 10: '7', 11: '8', 12: '9', 13: 'a', 14: 'b', 15: 'c', 16: 'd', 17: 'e', 18: 'f', 19: 'g', 20: 'h', 21: 'i', 22: 'j', 23: 'k', 24: 'l', 25: 'm', 26: 'n', 27: 'o', 28: 'p', 29: 'q', 30: 'r', 31: 's', 32: 't', 33: 'u', 34: 'v', 35: 'w', 36: 'x', 37: 'y', 38: 'z'}

# %%
### GRADED FUNCTION: clip

def clip(gradients, maxValue):
    '''
    Clips the gradients' values between minimum and maximum.
    
    Arguments:
    gradients -- a dictionary containing the gradients "dWaa", "dWax", "dWya", "db", "dby"
    maxValue -- everything above this number is set to this number, and everything less than -maxValue is set to -maxValue
    
    Returns: 
    gradients -- a dictionary with the clipped gradients.
    '''
    
    dWaa, dWax, dWya, db, dby = gradients['dWaa'], gradients['dWax'], gradients['dWya'], gradients['db'], gradients['dby']
   
    ### START CODE HERE ###
    # clip to mitigate exploding gradients, loop over [dWax, dWaa, dWya, db, dby]. (≈2 lines)
    for gradient in [dWax, dWaa, dWya, db, dby]:
        np.clip(gradient,-maxValue,maxValue,out=gradient)
    ### END CODE HERE ###
    
    gradients = {"dWaa": dWaa, "dWax": dWax, "dWya": dWya, "db": db, "dby": dby}
    
    return gradients

# %%
# GRADED FUNCTION: sample

def sample(parameters, char_to_ix):
    """
    Sample a sequence of characters according to a sequence of probability distributions output of the RNN

    Arguments:
    parameters -- python dictionary containing the parameters Waa, Wax, Wya, by, and b. 
    char_to_ix -- python dictionary mapping each character to an index.
    seed -- used for grading purposes. Do not worry about it.

    Returns:
    indices -- a list of length n containing the indices of the sampled characters.
    """
    
    # Retrieve parameters and relevant shapes from "parameters" dictionary
    Waa, Wax, Wya, by, b = parameters['Waa'], parameters['Wax'], parameters['Wya'], parameters['by'], parameters['b']
    vocab_size = by.shape[0]
    n_a = Waa.shape[1]
    
    ### START CODE HERE ###
    # Step 1: Create the one-hot vector x for the first character (initializing the sequence generation). (≈1 line)
    x = np.zeros((vocab_size,1))
    # Step 1': Initialize a_prev as zeros (≈1 line)
    a_prev = np.zeros((n_a,1))
    
    # Create an empty list of indices, this is the list which will contain the list of indices of the characters to generate (≈1 line)
    indices = []
    
    # Idx is a flag to detect a newline character, we initialize it to -1
    idx = -1 
    
    # Loop over time-steps t. At each time-step, sample a character from a probability distribution and append 
    # its index to "indices". We'll stop if we reach 50 characters (which should be very unlikely with a well 
    # trained model), which helps debugging and prevents entering an infinite loop. 
    counter = 0
    newline_character = char_to_ix['\n']
    
    while (idx != newline_character and counter != 50):
        
        # Step 2: Forward propagate x using the equations (1), (2) and (3)
        a = np.tanh(np.add(np.add(np.matmul(Wax,x),np.matmul(Waa,a_prev)),b))
        z = np.add(np.matmul(Wya,a),by)
        y = softmax(z)
        
        # for grading purposes
        #np.random.seed(counter+seed) 
        
        # Step 3: Sample the index of a character within the vocabulary from the probability distribution y
        idx = np.random.choice(np.arange(39
                                        ), p = y.ravel())

        # Append the index to "indices"
        indices.append(idx)
        
        # Step 4: Overwrite the input character as the one corresponding to the sampled index.
        x = np.zeros((vocab_size,1))
        x[idx] = 1
        
        # Update "a_prev" to be "a"
        a_prev = a
        
        # for grading purposes
        #seed += 1
        counter +=1
        
    ### END CODE HERE ###

    if (counter == 50):
        indices.append(char_to_ix['\n'])
    
    return indices

# %%
def optimize(X,Y,a_prev,parameters,learning_rate=0.01):
    loss,cache=rnn_forward(X,Y,a_prev,parameters)
    gradients,a=rnn_backward(X,Y,parameters,cache)
    gradients=clip(gradients,5)
    parameters=update_parameters(parameters,gradients,learning_rate)
    return loss,gradients,a[len(X)-1]

# %%
def model(data,ix_to_char,char_to_ix,num_iterations=1000000,n_a=50,a_names=7,vocab_size=39):
    n_x,n_y=vocab_size,vocab_size
    parameters=initialize_parameters(n_a,n_x,n_y)
    loss=get_initial_loss(vocab_size,a_names)
    with open("combined.txt",encoding='utf8') as f:
        examples=f.readlines()
    examples=[x.lower().strip() for x in examples]
    np.random.shuffle(examples)
    a_prev=np.zeros((n_a,1))
    for j in range(num_iterations):
        index=j%len(examples)
        X=[None]+[char_to_ix[ch] for ch in examples[index]]
        Y=X[1:]+[char_to_ix["\n"]]
        curr_loss,gradients,a_prev=optimize(X,Y,a_prev,parameters,learning_rate=0.01)
        loss=smooth(loss,curr_loss)
        if j%2000==0:
            print('Iteration: %d, Loss %f' % (j,loss) + '\n')
            for name in range(a_names):
                sampled_indices=sample(parameters,char_to_ix)
                print_sample(sampled_indices,ix_to_char)
            print('\n')
    return parameters

# %%
parameters=model(data,ix_to_char,char_to_ix)
# Out:
# Iteration: 0, Loss 25.648594
#
# Ownsd44my
# Rc89pvj01mk1zfed.rcgjd
# Mw43z22
# Brcg3p63559th4v11ehhqwhqarvinwn69at2pawg.kus71h6
# P68ig5r8fb2nc5.radtqu4ev6nfjb6pb5xe
# Pixbk6
# Bzoiz.e4bd71qqif5.w7ajk ljfcm92mplccwod
#
#
# Iteration: 2000, Loss 37.488695
#
# Yicbote er sesteotdu.deag laa
# Rimidt
# Bewdodtewtirk
# Gasgbein
# Hhescarabe lkek
# E lal n
# Vrar kfirirts
#
#
# Iteration: 4000, Loss 35.698545
#
# Biejyis
# Vocleod hore
# Marknem
#  daston
# Sichry
# Addrevyinnerw kdiingkootgety bed arobe
# Ledur
#
#
# Iteration: 6000, Loss 34.163457
#
# Gnexondander
# Plat
# Alaran
# Cooca papkee 0pppindene peridte fbanf
# Dlerke
# Phetreme
# Bwy san me5mamker afrima grckuf
#
#
# Iteration: 8000, Loss 33.701684
#
# Tomp hinto
# Janigh
# Uofler
# Zaray
# Oorinn
# Exa kex
# Arprotomsrey naller cayebo
#
#
# Iteration: 10000, Loss 32.839182
#
# Hova
# Leshlin
# Geronker
# Rivstise
# Suce
# Dr cat cenche
# Aura
#
#
# Iteration: 12000, Loss 32.681816
#
# Bean
# Orisich wouclor
# Bidch  gald
# 3as phepore
# Herf
# Mand
# Mwiini
#
#
# Iteration: 14000, Loss 32.489583
#
# Annida
# Menjiens sexy sexy stcl gotet
# Illess
# Letresk doll
# Haete g liggle nugat ongarings lidghe surery ciple
# Tenin euspyanie
# Pyereay hetthe warse
#
#
# Iteration: 16000, Loss 31.575767
#
# Scarraccest
# Plangoin
# Ofryer
# Meaprabooprry stupribonsa
# Revpe bldce caithin wamt ruaskneshebuce
# Keica ruscobstrarzainge
# Onvieos pob
#
#
# Iteration: 18000, Loss 31.932808
#
# Deerighthin
# Kanc durmands
# Pole sexy gra pirabe
# M2mars
# Chacilone moakin
# Focdase
# Bucting
#
#
# Iteration: 20000, Loss 31.641317
#
# Ponaber
# Pungit
# Pethore
# Pin
# Dagh
# Quxpumis deammi
# Hered ropter
#
#
# Iteration: 22000, Loss 31.087203
#
# Plibtten
# Shleomt
# Birot
# Khea
# Mam rober
# Mid
# 2leeg
#
#
# Iteration: 24000, Loss 31.409004
#
# Haplon
# Diiner
# Pi
# Cawierause ham heane
# Ce ombudard onouasie cho chemhatrif pagia
# Demomommen
# Piel waramer
#
#
# Iteration: 26000, Loss 31.034028
#
# Dofledinwe
# Pinsak tre in moncorpre
# Find sude hoia ban
# Torlfa
# Wits
# Bite veen hetluy
# Scherin fuee gowmus
#
#
# Iteration: 28000, Loss 30.648648
#
# Manion
# Leerla pretse gaistist
# Blomble
# Flees
# Sturk
# Rethded
# Litwiwer
#
#
# Iteration: 30000, Loss 31.203601
#
# Gmonnees
# Piruicald
# Ckelay
# Fourala
# Gand
# Maneal art loctanders puelad merockintburse
# Boonech
#
#
# Iteration: 32000, Loss 31.164497
#
# Sexy land
# Sexmij woffin
# Vam
# Bot
# Dowiratery all
# Devime
# Caller d thoon
#
#
# Iteration: 34000, Loss 30.481566
#
# Vidra minky teisair cet cotse dinjo jeek
# Tho mider
# Pirse
# Magonskees mons
# Fon
# Themul
# Munky butfist
#
#
# Iteration: 36000, Loss 30.428803
#
# Maackelele ragin
# Parth startaul
# Peety nuro
# Will
# Hy coman bares
# Spiler claver opumy
# Destretrin
#
#
# Iteration: 38000, Loss 31.085507
#
# Gartby
# Say dig oll
# Nubate
# Pobotade
# Zembkachsplaanon cotain tcarpa fbumaal
# Winf
# Snauda baby nick co dyor bly orndomo
#
#
# Iteration: 40000, Loss 30.185249
#
# Cead ictmdulke
# Mhobarma reflye blote
# Qureradrejelrabol
# E picher
# Boon spyes
# Sanienbion
# Pumen
#
#
# Iteration: 42000, Loss 30.673204
#
# Padar
# The on jat
# Teurl
# Uy iotoo
# Wibse
# Crodnestuil dobticorey lmince than ce
# Chicel bnie andie beaups cen and witteboun
#
#
# Iteration: 44000, Loss 30.614396
#
# Ghoch
# Schond
# Snider
# Chow m9x0enibot
# Klizetfiin
# Permamon the
# Veing watamwe tister grinstice
#
#
# Iteration: 46000, Loss 30.385649
#
# Parklloban mox pistor on peeplace
# Spider mas
# Moman
# Pitny tussumal
# Pidy a kelsond
# Pizolba tho
# Vamperlong dove
#
#
# Iteration: 48000, Loss 31.287191
#
# Thenide
# Zerint rogo
# Storonjactey
# Glerpon toodess
# Sexy booths
# Vampain onger
# Scairintter anler jat
#
#
# Iteration: 50000, Loss 30.254581
#
# Poner rlyal lyen
# Porty dibalf blottannila
# Pivad
# Powbe
# Womblown
# Pidurto
# War.flawble
#
#
# Iteration: 52000, Loss 30.324964
#
# Hed can
# Pag lloby lig cun
# Stira gisen
# Sirenchit
# Umboll
# Damdcleapbumeder
# Spunnce conatte girlo
#
#
# Iteration: 54000, Loss 30.481558
#
# Coptle
# Crivite
# Tery dold
# Chiretbord
# Peessfrie sleater
# Tatmanel man tras cak dusoprockocher
# Dexy pitke strask
#
#
# Iteration: 56000, Loss 30.111993
#
# Cherro
# Placuty smin
# The swute trol us
# Distin
# Sado
# Chisan
# Spircrin
#
#
# Iteration: 58000, Loss 30.438947
#
# The ty mariel zinjor flish clactaros winzo
# Pembleag the pueresd gu
# Gragillepuram
# Cish currultun
# The wofhill
# Jeanestick ll ginot
# Prime
#
#
# Iteration: 60000, Loss 30.456295
#
# Fartok satslent
# Dairy scothal shoit batame
# Frith
# A prockires airy cess
# Durthe
# Coutare
# Padist
#
#
# Iteration: 62000, Loss 29.771540
#
# Scy copottlelssurogh
# Bekebbet ragunim
# Graper
# Girl
# The bolidjeg
# Lambiman
# Thi
#
#
# Iteration: 64000, Loss 30.319324
#
# Memin
# Skinete
# Wearo
# Giwinn sexy moncercher
# Genear meg
# Dead bead
# Read
#
#
# Iteration: 66000, Loss 30.115655
#
# Chistus
# Trevam
# Seicos burd gunfar chenes
# Chein
# Shickinstanked bell vardinaper
# Mams
# Dodosbie
#
#
# Iteration: 68000, Loss 29.665248
#
# Berf kelly kold
# Butzolnty darn
# Hoth bothurgas
# Menter loby
# Parend yoor
# The sago8sursexy jonter
# Shore ponkelionenal josm alang  foothboy jock
#
#
# Iteration: 70000, Loss 30.076570
#
# Tuns
# Thand
# Porther sase wegopphate
# Zaracrow
# Pock raveks clown
# Pecue
# Booper
#
#
# Iteration: 72000, Loss 30.171104
#
# The rappye
# Drething rinatar costuman
# Catcie corkain babun
# Platey afuales enster
# Phyne gin
# Zabsty piratude
# Verie balry fable frannu adevghty scraccy
#
#
# Iteration: 74000, Loss 29.685416
#
# Wnikens
# Waig dog
# Back
# Cappewnit
# Daftaballe nank
# Dowk
# Toral g tachanesha
#
#
# Iteration: 76000, Loss 29.692992
#
# Tolle pangion
# Wingbidess
# Ddon
# The oom cruetuth cruen
# Costume
# Tree oder
# Peater and waage chistlewoyberin
#
#
# Iteration: 78000, Loss 30.360327
#
# Ty lown
# Ghady
# Dara
# The witjl kincat argit
# Pen
# Spitch ie balman
# Tombumor
#
#
# Iteration: 80000, Loss 29.313102
#
# Grivillar
# Mamandine s mann man
# Sapp preim
# Dacla mary
# Matho
# Piky
# Cally gird litt
#
#
# Iteration: 82000, Loss 29.687012
#
# Wempt
# The terbang
# P gsiy biwbewhert
# Jisrein of sexy noylle hatthe
# Junker wise the clowig
# The foom spersian kesweng gitly hildely
# Hold
#
#
# Iteration: 84000, Loss 30.049938
#
# Baz
# Groms
# Regre charo ninfist
# Tor the
# Fax on ice hazzol bindn
# Cactafa
# Witter
#
#
# Iteration: 86000, Loss 29.641357
#
# Tren
# Snisp
# Cosoo truntreld
# Terise
# Tha the man
# Waltard prink
# Terust
#
#
# Iteration: 88000, Loss 30.151230
#
# Lothen treepplon ay nandie
# Priend
# Gowt
# Scargleterfstere
# Tanniack
# Scarchum boy
# Pidarist dest
#
#
# Iteration: 90000, Loss 29.734160
#
# Queiry
# The sudyuveydary
# Scogokgluc an couchunt
# Jouel gholle conterlest
# Pake cume privin hostury
# The outher bittain getcemer foretiel
# Spachane
#
#
# Iteration: 92000, Loss 29.620662
#
# Cheppechivenks dozzor
# Mor. of llg
# Catme
# Hots
# Jertapeadends
# Weonkel sexy fego
# Cesmure balse sexy
#
#
# Iteration: 94000, Loss 30.157094
#
# Jake
# Monker
# Batmpstut
# The pirecie ph crom sard kizm nombalty frown
# Stith bottain lat
# Hobi
# Portaron
#
#
# Iteration: 96000, Loss 29.796729
#
# Vemicar
# Ghostisa
# Deteneepain
# Selly
# Naybus
# Paba
# Sepond
#
#
# Iteration: 98000, Loss 29.592875
#
# Marmslyman
# Poppy
# Perpher
# The
# Dnada
# Sex7g3muisebbammuller pumpk wiggot mersey anoothor
# Spice habatrese
#
#
# Iteration: 100000, Loss 29.738966
#
# Sperpin
# Jeon
# Cloon
# Sexy speles
# Citmeinda ander
# Tievic ficess
# Weankery
#
#
# Iteration: 102000, Loss 29.541964
#
# Pappascta paguntra
# Cash
# Dancoon
# Vonald
# Dupprin
# Fewi
# Potter
#
#
# Iteration: 104000, Loss 29.848644
#
# Betostinayl ann dosto dectytritch
# Clourkdramon
# Benices
# Ge cchil kelf rlboat
# Pas kean mat cevin bast
# Blarmut
# Mag
#
#
# Iteration: 106000, Loss 29.630923
#
# Percess
# Shadehrea
# Vampire
# Thra
# Thorabeviron
# Perth
# 0lirg
#
#
# Iteration: 108000, Loss 29.165865
#
# Black fylorsegeo floter an mokan adr coutle
# Sumer dimbsken
# Jolkebyld aitter
# Mast emone
# Pritabaman ieetele
# Pued cake
# Slpornen
#
#
# Iteration: 110000, Loss 29.665905
#
# Shova
# Nue anter gooptann
# Parda
# Car
# Berram piraper
# Pirerindam smqutta firy
# Vadd
#
#
# Iteration: 112000, Loss 29.704964
#
# Jpiance microndn
# Nat gins darg orguira urgec ratmot iose
# Siat frimbekcheastimleplepuy
# Waty
# Jeamiowinjlead
# Mutuar miths flara star tir
# Mesctewon
#
#
# Iteration: 114000, Loss 29.171104
#
# Daggre gurd dulliz ghost
# Tht a praider
# 19gr.ster bat
# Chretorn
# Vercon zerrio clander
# D skust giwam
# Ten
#
#
# Iteration: 116000, Loss 29.630788
#
# Pirm mario
# Zombade cower sous inonie gome
# Ggert
# Delybuck
# Vall jolfa sarrid
# Vidy
# Saxd punkflorllader witt daculie provil cice
#
#
# Iteration: 118000, Loss 29.567137
#
# Painoch jart
# Moctort
# Lous
# Costumo
# Danken
#  hobo
# Sexlisco
#
#
# Iteration: 120000, Loss 29.060308
#
# Beepy gay aniver clown lleypad trice
# Saulle c.leger
# Pame  320laton
# Fursc oith k ninfer
# Vauderine
# Metoral waqdup killigy cat
# Manclenesc degel
#
#
# Iteration: 122000, Loss 29.284353
#
# Thiwo
# Boon
# Blopy
# Therais
# Wenscred litt baplop
# Werster dunsessclamble
# Bearyflore
#
#
# Iteration: 124000, Loss 29.793399
#
# Bollesler
# Frock mooser
# Jack boybberst highthass ghostd ginder addel tcaur
# Man
# Slerbatsin besseatter
# Dnery
# Teder ligst can igry t odboy
# Iteration: 126000, Loss 28.881354
#
# Sppo
# N thammst
# Siper anmir s4omanid
# Spourth acentia
# Vothta theenteric ich
# Schee
# Srada
#
#
# Iteration: 128000, Loss 29.249254
#
# Chesce
# Pulny pennyoshron
# Zamperer
# Seddlesqoge
# Keddl the zareme
# Phich ean
# Pirowersenslalde cduttlet
#
#
# Iteration: 130000, Loss 29.455819
#
# Penny numons
# Cottaus
# Bunn
# Pink
# Buss
# Ther
# Twist
#
#
# Iteration: 132000, Loss 29.213103
#
# Shicgar staluspcrrois
# Pan
# Zorderron
# Doniek whinziboon
# Mad meter quertiing
# The cizzer
# Scape giol
#
#
# Iteration: 134000, Loss 30.012584
#
# Glocops
# Pradeen lick and frasondury
# Tedter fotter
# Homes wigwogor
# Bilby divard
# Starewol
# Princlerbers
#
#
# Iteration: 136000, Loss 28.989955
#
# Gook  oostong
# Teuchon
# Runger
# Shorner
# Sad worrod pony the ghirlemder oft
# Dampy wold oots
# Petele
#
#
# Iteration: 138000, Loss 29.279317
#
# Collie of wizzo
# The fall whre
# Jen
# Bldend
# The veelles tlenst
# Pein
# Pan
#
#
# Iteration: 140000, Loss 29.497925
#
# Sexy suremy witch nun cape phing beth sancler
# Janled dattast
# Sixy
# Cat  quit
# Zobblost
# Redead minky scubek
# Princepoy
#
#
# Iteration: 142000, Loss 29.169146
#
# Jewleder
# The stap pad
# Tererusk
# Thile man
# Derimbit
# Sexy crim direprace van
# Seva costuino
#
#
# Iteration: 144000, Loss 29.624782
#
# Puth al aliina derdoa
# Freep syotick enia
# Quariny
# Jook
# Pleeg
# Marina queeny pank ration
# Mad
#
#
# Iteration: 146000, Loss 29.645099
#
# Palvne gumbler
# Wita onice
# Berdic wighor
# Pirck
# Devil
# Sexy scary hinsery ninja
# Shy ing
#
#
# Iteration: 148000, Loss 29.072492
#
# Griischer
# Jothed chaleth watery dricel
# Dzeny card guinia
# The cou chimoth deectach
# Sandie
# Tidzockulid
# Penkeplaleth ginder
#
#
# Iteration: 150000, Loss 29.338821
#
# Vampning f1rf gi krleear
# Grade
# Peachon octow
# Peserlistchasppee
# Moctonk chee speril
# Pictaenicy faxfsthe gurs
# Plurce
#
#
# Iteration: 152000, Loss 29.341039
#
# Poppiuguy tonteriane couptyper mennuing d malla
# Seurmpirans angnsbegnoa
# Dark
# Thate
# Bang lock pachirn
# Sluinscy pan avriagan
# San3a pealamol
#
#
# Iteration: 154000, Loss 28.843768
#
# Maike
# The kame
# Spost garror moznt
# Sexy menn oxy andold
# Sexy man
# Thing
# Zaspur
#
#
# Iteration: 156000, Loss 29.167542
#
# Ghavala
# Pior
# Pling bikenist
# Bestot
# The sexy king wenic clown
# Pizviv sany tiniin stt
# Saivalbanes
#
#
# Iteration: 158000, Loss 29.045842
#
# Thous
# Mjinger dav
# Ghiccor
# Devil hrlych
# Peand mrilh trbil traime
# Jamplinz ochorladgatr
# Deughtion
#
#
# Iteration: 160000, Loss 28.855819
#
# Sooky
# The punkep
# Stapire
# Tht
# Spargotixy
# Been
# Zampursors
#
#
# Iteration: 162000, Loss 29.134538
#
# With spio lodse
# Mader
# Horr
# Dover drummat
# Doctos
# Cuilter
# Jenice
#
#
# Iteration: 164000, Loss 29.328950
#
# Parper
# Cat
# Plink cheeper
# Capherle
# Copbey sobie dog mogg ban boderevill
# The gargonsty ming the jenarw rock
# Daldne golaweed womered
#
#
# Iteration: 166000, Loss 28.604411
#
# Pry
# Cloml chead carty
# Pad of tonste
# Clingle
# Bust
# Wera
# Scark
#
#
# Iteration: 168000, Loss 28.700060
#
# Swiper
# Swank qurrm rangera hunny
# Wenchurs
# Sop
# Termamph
# Cead on angied desper
# Gwipbist
#
#
# Iteration: 170000, Loss 29.400735
#
# The pyake
# The flayk sundon
# Vamy rock
# Cadeked disk
# Delet
# Sexy hell gitmnie sleer froaf
# Cy koby
#
#
# Iteration: 172000, Loss 28.755529
#
# Swok
# Shash
# Vander
# Memse
# Sluerols vish wit angesse
# Sexy podpembie anosl hord of ibut
# Por
#
#
# Iteration: 174000, Loss 29.272866
#
# Gigiok an mar spidjridendbeicai
# Shince
# Perphe
# Zombey
# Pennad
# Princes
# Diegean muck
#
#
# Iteration: 176000, Loss 29.362480
#
# Tobalon mertiss
# Trver
# Primoc
# Boes cooball
# Twea
# Caslacek a cva cloet queuts of msty ander
# Packins
#
#
# Iteration: 178000, Loss 29.053870
#
# Dont gher
# Th hebuc co stengerm
# Polache beres tcqughth man
# The jeeper
# Telane
# Thintist
# Telow
#
#
# Iteration: 180000, Loss 29.814922
#
# 070ectirot
# Sexy bampiral pridingar
# Zelth mabnot ckincett
# Zeltein straer
# Zese
# Jether
# Petal
#
#
# Iteration: 182000, Loss 28.899088
#
# Ginch
# The pirdeletege
# Boker
# Veven
# Coct
# Frankicer
# Mick nigs mos pome s skatanaurmomwoman
#
#
# Iteration: 184000, Loss 28.968462
#
# Thalage
# Sard mard marlkel grasthesey smaingertamul bater b
# Clin
# Bunfite razamkitling bonnster mrank
# Thinfte honst
# Che
# Weypla
#
#
# Iteration: 186000, Loss 29.236698
#
# Wispps grow purple noty picent eick fail
# Sson plind
# Ticer
# Zeldamfs tr.
# Propteg
# Fliak hardise
# Queen the pippeal
#
#
# Iteration: 188000, Loss 28.674354
#
# Kat kizza kith
# Terwitwin
# Slol yikzer of brage stale antrant
# Terleva ridoct
# Kin
# Gam jonger
# Vampion
#
#
# Iteration: 190000, Loss 29.244446
#
# Jemplerivers
# Sexy loura thiper
# The fstume
# Tel rufs cobburg
# Dold tuddy
# Tho y pofthe
# Tumen siccosesacrea
#
#
# Iteration: 192000, Loss 29.249389
#
# Peret benie
# Sadd m tart
# Pobeumy
# Jefestount screkman
# Shista c2sese bellatring mady
# Jace chess
# Vafase
#
#
# Iteration: 194000, Loss 28.476320
#
# Those
# Sexy marro
# Weter ponate
# Vemanar
# Dno
# Perthe girazetucesuthentwisser
# Dight ban
#
#
# Iteration: 196000, Loss 29.093782
#
# Zolder witch
# Pace
# Of am rezherot
# Wonstehol
# Sexy how
# Danda
# Vevilourp
#
#
# Iteration: 198000, Loss 29.047283
#
# Batmam bosturfki
# Zomba
# Then
# Gipper mat grfeg arscobbarrin rom jennine
# Thtcoss lybardess
# Magan ginder dratara
# Rom
#
#
# Iteration: 200000, Loss 28.700158
#
# Scumpn
# Pool
# Dant sluteen le sa sundery gossus pan
# Gin
# Piue
# Spiue
# Sooppeg
#
#
# Iteration: 202000, Loss 28.984096
#
# Dny insie
# Dracle hob thina
# Thore buldors s
# Frigcesbeauth
# Pilatiang ofitele
# Blamentherman
# Demisburg
#
#
# Iteration: 204000, Loss 29.190328
#
# Coptia
# Sperpe
# Jengeref gundelise hroble jonster
# Shoretrank wazo
# Vad eltihgerse h
# Crasou sperettrra drustybll frickbirper  cloctale
# Pat baby
#
#
# Iteration: 206000, Loss 28.662511
#
# Thack dondarga
# Selefire garncar bremor
# Turekrogguin dodob spagle womprre
# Zanluid witcarr
# Witce dien
# Witse dotroowbeg
# Pothugsaoberpor
#
#
# Iteration: 208000, Loss 29.034491
#
# Geetre eithulled marmeningbettis trichie
# Deng buctheh
# Veenagsosting terthes ly binn of wilas
# Docter
# Slunnayhne bangerman
# Shanetter mindiala
# Plunt stulphie
#
#
# Iteration: 210000, Loss 29.213041
#
# The of
# Cosingollybarbeans
# Ghostutighy clown
# Terrus
# Blobo
# Taturiggread prom grarro
# 8an
#
#
# Iteration: 212000, Loss 28.271802
#
# Spidtie grack sexy mea
# Cout s chead shalk
# Role
# Lapetch
# Sexy chight gan
# Shabldant bunmon
# Jady s shnersexshallk
#
#
# Iteration: 214000, Loss 28.748474
#
# Grilingia
# The ronguy
# The chack
# Ghost
# The hathy cuse
# Zinnise
# Chown in pinkait
#
#
# Iteration: 216000, Loss 29.075644
#
# Phimair the quince nichon
# Bunger bumpydealeclely
# Gharksy
# Pone
# Narbs
# Dantion
# B pirist lat man
#
#
# Iteration: 218000, Loss 28.934333
#
# Ugelst
# The feit sexy amoz
# The in bleen overin
# Wele trump ja
# Peink of map wady unguit
# Man
# The s mif 800iz ake prinel maleyvi
#
#
# Iteration: 220000, Loss 29.420788
#
# Plaat anister
# Crom
# Surt
# Princess
# Thrll ny cowbicer
# Noym
# Penction cinh
#
#
# Iteration: 222000, Loss 28.855165
#
# Jood
# Tean peint
# Dendejlig
# Ms. harad yooda
# Deri
# Dantors
# Theninegont
#
#
# Iteration: 224000, Loss 28.766118
#
# Mannes
# Pank toodwos  coler fregerle cotctwold witge boxex
# The berlline
# Vecrests litry wankenler
# Peagee
# Assty untens spirines
# Bath
#
#
# Iteration: 226000, Loss 29.540119
#
# The kingmor
# Thouflingiverescisegoen bear
# Pirase
# Pench wizchumbi
# M sexy strincry
# The rock
# Vqule
#
#
# Iteration: 228000, Loss 29.203332
#
# Jack us
# Placka deston veen alow dren bunf
# Dunnie skerien
# The puter butumplie anden oninter
# Devil
# Jack meii
# 1ebe ruth pinaher
#
#
# Iteration: 230000, Loss 29.099453
#
# Daromen
# Pojamojelicara
# Malshery rand lermuead gere
# Sspy philo dongiron
# Faise
# Bocuster peker
# Thapl
#
#
# Iteration: 232000, Loss 29.072186
#
# Turk
# Jatty chady ofagenske woachus
# Clipplint
# Bot lipyer fredicat
# The gin
# C lits
# Bog
#
#
# Iteration: 234000, Loss 28.698261
#
# Pptrey betorlaldderfviter suor teviberman climens
#
# Sten
# Witch
# Zalda giele or yonk
# Thoron a guit
# Tho
# Sexy fran sicumd
#
#
# Iteration: 236000, Loss 29.231827
#
# Jrosh
# Dmon
# Beomed doctirstura woingbl boot
# Woba
# Comsinger
# Choon cat woid
# Coam
#
#
# Iteration: 238000, Loss 29.013231
#
# Sexy kienkengeration
# Piden
# Pizza clock vad wolfcy pord pack
# Princel clom sexy maker
# Haruper cich unime
# Prow clacticath dead of chegry dom darobostato
# Wuide
#
#
# Iteration: 240000, Loss 28.629878
#
# Merire
# Lluty mi.s spias
# Scontarh
# 194 mue
# Donahger cerplater
# Whocal  centyler sgumanach
# Ther
#
#
# Iteration: 242000, Loss 28.921658
#
# Carmern
# Daan
# Sexy laniel
# Gar
# Cowshar the afs trul olterbessty
# Gandestar thah
# Cat
#
#
# Iteration: 244000, Loss 28.937056
#
# Cove
# Manvan man
# Pongel drenster
# Tharale wom ovaser
# Medsess einal fficercerus wlicer
# Pippiresors
# Meustim graintethis homerespie biggal whaus
#
#
# Iteration: 246000, Loss 28.434338
#
# Jactiro  cueen
# Ghos
# Redled hook
# Swompill
# Boofthronion
# Joon wirkinglesnithmpid
# Theg
# Iteration: 248000, Loss 28.989333
#
# Godd
# The woba
# Devey
# Beall
# Player werle surthers
# Werehirghnoake
# 5ossterc
#
#
# Iteration: 250000, Loss 29.171861
#
# Pitter
# Pactant
# Vambi
# Peter
# Wolf s crasmine
# Binde
# Caphar
#
#
# Iteration: 252000, Loss 28.422471
#
# Arm
# Parpit
# Shosta
# Hail lelisr
# Meer
# Proahtry
# Pith
#
#
# Iteration: 254000, Loss 28.458204
#
# Scarea kinghernaun
# Jlelladizoga baaness
# Pawnio ded
# Spider
# The angilzata punk marter
# Jumty girbedd
# Weeanctybing gangman
#
#
# Iteration: 256000, Loss 29.428313
#
# Twarken
# Pacry tumc pirate  fighty panen can anssa
# Popepesex
# Teb cosh sexy cicewbavi
# Womokie berss
# Terton putereric thedon
# Thost
#
#
# Iteration: 258000, Loss 28.368372
#
# Pringer
# Coge wotron queed brim rld
# Male
# Pefitor
# Drintant
# Maper
# Pentelf man
#
#
# Iteration: 260000, Loss 28.702100
#
# Coin a bleandhels
# Peake chinle
# Pbrho main hobotut
# Prince umust
# Sexy coghn sic
# Cloin schgll
# Midpennerss indel
#
#
# Iteration: 262000, Loss 28.930227
#
# The vamp s srai
# Parl
# Fartords
# Gharmurg ost
# Twi
# Plipth spavain krughocap siidaur
# Coop
#
#
# Iteration: 264000, Loss 28.861777
#
# Manch
# The wobue
# Sbostus angautimiosh
# Ganjaitt firn
# Trunken cat
# Dostal
# Zomny the rurst
#
#
# Iteration: 266000, Loss 29.692280
#
# Guety
# Pawer
# Zomning oat qut
# Cit
# Fuine rotticry
# Bog
# The ghost fotian
#
#
# Iteration: 268000, Loss 28.794867
#
# Piz sexd luguntere 1axochs captorle
# Medisssmisard langedermes bell
# Patod danterg
# The batle adaloof
# Refishiraal
# Jeen
# Salen
#
#
# Iteration: 270000, Loss 28.720766
#
# Piray wilffie wina
# Panthe medumuy wisper fironan unicet
# Petter the
# Telleng rate
# Ghoseicer
# Gigmgie
# Zombae pever pringy vexxxxxxxxxxxxxxxxxxxxxxxxxxxx
#
#
# Iteration: 272000, Loss 28.832387
#
# Thfling
# Venain
# Te
# Dowster
# Thter
# Clueky bad parrymalf preddaveshing piratre
# Tree pas nurdideva bat pootlazen
#
#
# Iteration: 274000, Loss 28.740342
#
# Tim
# Weara
# Pan
# Mexc
# Serdish
# The furgon icorpin
# Trant belmed appnand hoot
#
#
# Iteration: 276000, Loss 28.995688
#
# Poy
# The rat
# Velepa
# Gralieslurs wander jock king d k in charrin vedoa
#
# Cing
# Pighich
# Reag
#
#
# Iteration: 278000, Loss 29.051971
#
# Sexylist
# Mantuar ceine
# Husk
# Pyne
# Zombirge
# Jotate nutt gurg
# 19catong
#
#
# Iteration: 280000, Loss 28.527252
#
# Son
# Mm. hen
# Zarteftb brodsle rosson
# Scido
# Danca
# Mailincesstrein
# Thoson
#
#
# Iteration: 282000, Loss 28.841070
#
# Pana moustenure othrather man
# Park
# Perder wmaviadangof
# Racter
# Pan
# Meice
# Ani
#
#
# Iteration: 284000, Loss 28.720197
#
# Pan
# Veller
# Wetrang
# Cood
# Rojde drunk araur
# Saty org hob wrack
# Track rermisued chiny
#
#
# Iteration: 286000, Loss 28.487189
#
# Jellay evinga ghost murde sane mentuge grunce man
#
# Pantin
# Dell
# Bet
# Minson
# Warronken pajus
# Gincor baby
#
#
# Iteration: 288000, Loss 28.731985
#
# The rmbing thiot
# Spairammatal tarver
# Treethinja
# Hobrec
# The screan
# The polist
# Thist bub
#
#
# Iteration: 290000, Loss 28.928534
#
# Jrisster s trippy monster carcha und puthh hook
# Grissch rut  frion
# Mousion
# Ternandin o0ty friln pirate dien
# Besc
# S. scomerint hotser
# Cowninjo tho
#
#
# Iteration: 292000, Loss 28.537961
#
# Mader
# Jardbowie dog ermedthuns
# The jacikn
# Vevssman
# Sexy pirate
# Slayek
# Stadan af roblot spirerre suitardam
#
#
# Iteration: 294000, Loss 28.645247
#
# Bergertagen
# Quiry
# Big lagon
# Quimbarbetin
# The box queen
# Beg
# Colaycroses
#
#
# Iteration: 296000, Loss 28.972321
#
# Vadstatcur
# 0ins thunch alperincuck
# Velite
# M1. lamp wlll lingor poorse
# Thug
# Verber brachelinskin
# Thepteremauthooppriuncon
#
#
# Iteration: 298000, Loss 28.083872
#
# Poleneim choun
# Vercas mctst
# Shig
# 1960pernal tarr
# Terowi
# Dacthe tron zombaimumgisbah
# Ronaher wizle pumpki
#
#
# Iteration: 300000, Loss 28.479326
#
# Weng mam sire busums
# Pilf dencosis
# Tahie jontilla binne
# Sona
# Noo
# Masa
# Mish pongian tumc  ffire firect punarma
#
#
# Iteration: 302000, Loss 29.130103
#
# Bubot danger
# The batel be mas shates
# Zorry
# Baby froged worker
# Ghost
# Joscy oner jertes
# Choef
#
#
# Iteration: 304000, Loss 28.429433
#
# The dalder
# The tuimade
# Shick of jowbist
# Zeor skeletokest
# Gro dall fleen
# Jader
# Sexy girlmgrown
#
#
# Iteration: 306000, Loss 28.980784
#
# Zenisus
# Tysait uttiwladosaurbettonkiog
# Charcdize
# Jextar faxa
# Picandan
# Devil
# Picabeyna
#
#
# Iteration: 308000, Loss 29.030864
#
# Man
# Jeag
# Rajal sacla
# Vot lle dracuth
# Sopher joma
# Zondess
# Simald
#
#
# Iteration: 310000, Loss 28.819557
#
# Pecper gamus dalddoy verie merdonearliem
# Zishion
# Gotmed from coumaess
# Sexy butzom gomcoxs fa eldigst
# To oa panzputh costume
# Zommit
# Doctor mad
#
#
# Iteration: 312000, Loss 29.485187
#
# Cat
# Ledenstumbus
# The stares chiewel
# Beavel gightywog
# 87thale
# Pothoan
# Wincant
#
#
# Iteration: 314000, Loss 28.806939
#
# Maskm kins genris
# Dorg
# Twman
# Temor
# Dusesion witcoober
# Strow
# Mybenimaida
#
#
# Iteration: 316000, Loss 28.604216
#
# Bana
# Carcy
# Bonnie wit
# Matto
# The gewadanne
# Sexy fpsznamgut
# Fale antara faiean and boan
#
#
# Iteration: 318000, Loss 28.824564
#
# Wizce dredspered scierho
# Thist flarumu
# Tiden
# Bead ad wizarin
# Choun
# Jeller biceriinoberse
# Pilon
#
#
# Iteration: 320000, Loss 28.456059
#
# Glanker old mad phot
# Hob twenthy toht pironk
# The misemaggox
# The dich pobe crazonk
# Velsor reds syelian caster
# Sheakie polaurase rotmetardto
# The womotuaty tistos
#
#
# Iteration: 322000, Loss 29.021482
#
# Whe sexiceleoson
# Ssuppien
# Jucked ofym ranain
# Sexy boodwirsco not sauron
# Connie
# Cape
# Smanzhas sffly ss. witce
#
#
# Iteration: 324000, Loss 29.065988
#
# Jurzer
# Beam
# Pan
# Weng ded quitte
# 1929  audplunglestist
# Jef doo
# Jagcosan
#
#
# Iteration: 326000, Loss 28.148430
#
# Genst
# Candy denism fooop
# Costum sopeuker
# Veana
# Denta mad merine
# Thand
# Werere
#
#
# Iteration: 328000, Loss 28.715676
#
# Sicer b8tmice
# Thee bun runa deablepet of zomler
# Ber sinnincess indina
# Bath tork checrean buety motter tooba rldial pient
# The coune ond nun
# Pornder pidor wombi me
# Pynner lesnins alety
#
#
# Iteration: 330000, Loss 28.817144
#
# Shinot
# Platumer
# Ther
# Poomh
# Tutreth
# Twing
# Tumaney
#
#
# Iteration: 332000, Loss 28.219403
#
# Spisker
# Galman
# Shog cel
# Zel
# Choh wely bay
# Teoader
# Spow hatle sink
#
#
# Iteration: 334000, Loss 28.663361
#
# Juncer
# Muticet
# Surne kinko
# Toder show
# Man
# Woer trive preeclef chien
# Scurjal kride scienxy the
#
#
# Iteration: 336000, Loss 29.088921
#
# Alaun
# Panchsfeed hed el fik ongu
# The rawmon
# Massuee moman
# Peampsesscad men maman steston ox
# Thoof
# Mad falaper fikentyar monger
#
#
# Iteration: 338000, Loss 28.306002
#
# Spanen buepper pirate bliscoll
# Vent
# Phape
# Gangurdes
# Stane renatitive  furp
# Moge treistus
# Gods flaerend ronlisi
#
#
# Iteration: 340000, Loss 28.436140
#
# Jutterban and emain
# Sexy lestle
# Dean
# Saxy tuck gait
# The a fursc freduin
# Jedsce burmeres
# Suighetron
#
#
# Iteration: 342000, Loss 28.929313
#
# Vamters
# Wolamacress wiznlasre the nutflacl  gr. flinky fro
# Slurta
# Zomme
# Tha ggallon
# Veverogey bella rid in a sla lig
# Velewener dolalie qbeg
#
#
# Iteration: 344000, Loss 27.852216
#
# Mac
# Voscy boo frack snaid
# The elf joffsky premph
# Thabede
# Pllf
# Golfter
# Moock
#
#
# Iteration: 346000, Loss 28.399278
#
# Scavan
# Sanadoos
# Piridckiry
# Phyppywird
# Bee
# Sexvina
# Quim on
#
#
# Iteration: 348000, Loss 28.855458
#
# Mumpkiolleno raum
# Tilo
# Shout
# Blasticingbary
# Pottealese
# The potterton pirn
# Penst sciud mugie bat
#
#
# Iteration: 350000, Loss 28.677406
#
# Cener marie merp
# Witexspideton
# Piling witg mefly linger ox
# The s fistongh
# Mim romon inting mokewswiry cheen
# Police
# Mobheroa plrie scient spramc inmo machroe winfrom
#
#
#
# Iteration: 352000, Loss 29.223948
#
# Thinarinecal phomor
# Jan
# Beldaws ro nirm chfwiba
# The hasks grara
# Jevengeytron phinger
# Cown
# Zomterfass
#
#
# Iteration: 354000, Loss 28.480234
#
# Ffesa
# Disburg
# Peal molld
# Dog
# Chob
# Cheftess
# Spoppymin heg
#
#
# Iteration: 356000, Loss 28.593636
#
# Nave
# Vestan
# Crure girg
# Tail
# The a fool bie the ame n
# Rax a schoen
# Turnoad mram sexy
#
#
# Iteration: 358000, Loss 29.169624
#
# Cluetcence
# Clown
# Than
# Cate
# Mat in mineley
# Doggs
# Ze
#
#
# Iteration: 360000, Loss 28.838404
#
# Jan
# Blue a rem ananing goss
# Ghosin
# Botter
# Phiun
# Zombie
# Z tliman gaullion
#
#
# Iteration: 362000, Loss 28.830599
#
# Clage
# Thinerthes
# D2stree
# Keca
# The
# Bellype wipss
# Frrilger
#
#
# Iteration: 364000, Loss 28.926576
#
# Mancesqugsole oicorn wala
# Sexy romas
# Bart
# Chopeler
# Just
# Sexy gil  age
# Sexy grofts
#
#
# Iteration: 366000, Loss 28.398655
#
# Rmbotim
# Couting
# Terkee
# 1ouper umbaburis charlsincer
# Jacus
# Tedghca golie sheecler peary
# Jead
#
#
# Iteration: 368000, Loss 28.718702
#
# Ma
# Barl gaho workion
# Zog
# Bums raty bridck mman
# Phon
# Joller
# Sacleejhiotbeester doosicg piratee
#
#
# Iteration: 370000, Loss 28.746459
#
# Vemble himiz
# Jedit
# Jesteon
# Tunk
# Peng fvim bestere
# Pheder
# Pen
#
#
# Iteration: 372000, Loss 28.232629
#
# Thekeser
# Booster
# Bluttue
# Bowblla tuilerur
# Tatiri sangirl
# Ter bobs aldiegersalf
# Sarthe sirver
# Iteration: 374000, Loss 28.584912
#
# Captain
# Therefssen
# Sexy the cleany martor
# Ter wibertd
# Pigare ginsburl
# Humper
# Jegmed
#
#
# Iteration: 376000, Loss 28.586948
#
# Fint
# Prack raprypet
# Firdal sexy ind beypermorri
# Ckapesstt
# Sampunter
# Fretter
# Girl
#
#
# Iteration: 378000, Loss 28.256485
#
# The fonald prish of gols
# Doli man
# Saden snaceloot
# Sheech ssoman
# Sexy shargs of toman lolit
# Sex  foory s maidion
# Jellers bugical pank witch
#
#
# Iteration: 380000, Loss 28.669621
#
# Giderberty
# Salat
# Bettanleg
# Bat
# Gransbightschabbuis
# Gait
# Ggerth
#
#
# Iteration: 382000, Loss 28.944156
#
# Justroworanaid garase
# Sexy dom wica
# Doft k0bro
# Pilather
# The jan
# The
# Jolk bridtuan
#
#
# Iteration: 384000, Loss 28.292547
#
# Pantus
# Vethars sclencor
# Ppefale and dicerair ank girt crimpiry puth princm
# Zome
# Pirncroal bratcro
# Sexy k beat
# Taro
#
#
# Iteration: 386000, Loss 28.293598
#
# Sail
# Zacuplar
# Temen
# Patain in thumen
# Zonching
# Gidnan
# Pwing basber
#
#
# Iteration: 388000, Loss 29.093304
#
# Printcmimer
# Nwols kddy
# Pichker
# Hadress cimen caridre candy clont
# The grinish
# Sibobadny gank
# Brift
#
#
# Iteration: 390000, Loss 28.114350
#
# Pnun
# Arru
# Man
# Rorhing drlubl
# Proja
# Hat huse
# Pirjhulk shard jaju
#
#
# Iteration: 392000, Loss 28.657921
#
# Chornen
# Chie a sperl watta friefs
# Trunn
# Sexy oin numpess
# The bow
# Tetherper
# Wirt
#
#
# Iteration: 394000, Loss 28.598366
#
# Jomarag pich sexsk in dracrio
# Catbust
# K flizrman
# 095lsbuns
# Goja mariivorica
# Bmurin andvart
# Sexy call
#
#
# Iteration: 396000, Loss 28.248670
#
# Hoad poke gizh
# Thab
# Jester
# Loustos wi
# Plenta buseld
# The ofd hurky ul
# Mint taiturst istup pond  cofbare stan terese
#
#
# Iteration: 398000, Loss 29.326819
#
# Tera incter
# Menuie faboy boy clown
# Masqsheybeadle girl ubsadit
# Cogrets
# Omy afe bbuman
# Vettonon wold
# Beetiandharmen hoot
#
#
# Iteration: 400000, Loss 28.270857
#
# Poocer
# Mamy man
# Saccoste and ald fromoumon
# Saridckilay pan
# Sady tuth mad hobita
# Somy
# Pimpirh alestard
#
#
# Iteration: 402000, Loss 28.535859
#
# The lepoll vigineed baby engackinfesmesssise
# Cola noble fexee cahmparal fatra girl
# Cear parrono
# Keedpheyrio tretor river xevar rotterselian
# Girl  xxxxxxxxxxxxxxxxxxxxxxsira
# Totitus
# Vampines gionakey
#
#
# Iteration: 404000, Loss 28.901477
#
# Jex tubley
# Gucy
# Drandster
# T.d auguril ap faxpenf
# Heapericbxen percwo
# Drack galder
# Weterthe the tella
#
#
# Iteration: 406000, Loss 28.681856
#
# Tho phirtat celpezont hust
# Phily trim blasy
# Killatl berkin charl cast from leach
# Fruzzor engut k puntebobls pord estustirnast
# Print parlam fur
# Jamptrena
# Grancesyped dinaikerton witch poclet
#
#
# Iteration: 408000, Loss 28.941403
#
# Jl whith gor
# Hantea queen
# Jank d meler stch clown
# Chot
# Quokif
# Fang carse
# Nate in wager
#
#
# Iteration: 410000, Loss 28.902939
#
# Tearin
# Herper
# Pratcorciba goos
# Ficre
# Ervees jefica flo  havess
# Tuit
# Zompi
#
#
# Iteration: 412000, Loss 28.131411
#
# Wimbaid guith bermer
# Maiby bambia
# Jondiallda
# Babyen
# Corsblachian
# Shocke
# Greek fromnie ginst
#
#
# Iteration: 414000, Loss 28.704161
#
# Cesen
# Tealeseliopadcank
# Swacacgoja
# Cow
# Monsseyed queen
# Tat
# Sexy perlobus of cheiprurs
#
#
# Iteration: 416000, Loss 28.812016
#
# Velly goburen
# Home
# Berte bumptie
# Mamil koliss
# Vet
# Je
# 1vygur
#
#
# Iteration: 418000, Loss 28.219915
#
# Wing
# Wighmete
# Mime minait tumpkindam
# Wexsped man
# Cald
# Cladary wirja snump
# The mine bestare
#
#
# Iteration: 420000, Loss 28.443311
#
# Feii fairy
# Alirico
# Beart
# Jompirebsach
# Suit
# Girder
# Bus
#
#
# Iteration: 422000, Loss 28.689337
#
# Penjes
# Wipleor
# Zocket
# Subuntard
# Thri
# Zombie corper
# The bubling hola
#
#
# Iteration: 424000, Loss 28.290335
#
# Gastouman
# The vode evide
# Prand oc wott
# Thinpet
# The llly witch with
# Vamanienoy in witch
# Sschebe amse dorghos
#
#
# Iteration: 426000, Loss 28.415131
#
# Cohlester
# Sax ghocmibofes
# Giostus
# Pantees
# Cunder boxst
# Bini
# Wormer
#
#
# Iteration: 428000, Loss 29.147919
#
# Weober gans rid qurmcer
# Sax
# Melie
# Chet  cuntem
# Pinger from hoop mmant  panter
# Gromms
# Visusis
#
#
# Iteration: 430000, Loss 28.004549
#
# Leganie loney mpimaboy laza
# W a sichieny girls doctor doclic wondery copy
# Sale
# Box
# Shosbas
# M
# Myed animaivim marbim tarealles
#
#
# Iteration: 432000, Loss 28.374218
#
# The boyndzvil ford monster
# Pomen
# Jolowerme
# Megger
# Good squsa
# Prayient cramgey lademo
# Thery
#
#
# Iteration: 434000, Loss 28.916522
#
# Sexy jan
# Ghygnaum
# Dnighthe
# Boball
# Jutuis dally syiciog
# Doncist
# Carra
#
#
# Iteration: 436000, Loss 28.502540
#
# Ton scio golist baadord
# S san
# Sexy with a pumut
# Mime
# Tush
# Racaid
# Zell durdorgon
#
#
# Iteration: 438000, Loss 29.073551
#
# Bstur
# Sacle surylicllus
# Mows might
# Count cypa
# Zock que
# Puth docsry
# Cature
#
#
# Iteration: 440000, Loss 28.624498
#
# Godzem hogs
# Punh tseberey ny oocken
# By enfina
# Gloche sexy prindess
# Black
# The desbuith ond dok
# Boy brick muddrimul
#
#
# Iteration: 442000, Loss 28.548439
#
# Vesper
# Ckif
# Ssulate
# Prirenessbee
# Veth thublicel sydrere berker
# Recl
# Redoakamed dratel
#
#
# Iteration: 444000, Loss 29.249440
#
# Jrales
# Clown
# Lobsteen
# Thdork
# Vellaes
# Tragen lrol the robobictok
# Thins
#
#
# Iteration: 446000, Loss 28.880857
#
# Mata
# Terne telly of turt
# Boot
# Jegeriron wontherigus
# The teri shillifaster scienter
# Terer
# Trins
#
#
# Iteration: 448000, Loss 28.677765
#
# Bottie and cturmonce
# Wig pozvenvi suider the faxp
# Compited rolotise
# Sexy
# Fit ghoso
# Chicker
# Pitht lobot
#
#
# Iteration: 450000, Loss 29.035083
#
# Jigo
# Jvil
# Turrow catter a rocker
# Come
# Porate of an
# Jestie dog
# The ghonot
#
#
# Iteration: 452000, Loss 28.757036
#
# Trespion
# Jeim
# Compck
# Droja phegtle
# Sexy el botter
# Slade spob
# Jemsme
#
#
# Iteration: 454000, Loss 29.200501
#
# Peeperiad mouine
# Pirater
# Sceecher
# Miks lob
# Kicline
# Jwilca pothit
# Dench
#
#
# Iteration: 456000, Loss 28.969852
#
# Prebad hert wimfabarder
# Dhaser
# Thringer
# Wild a s witch
# Shaghtomas
# Wind warn
# Pray disder
#
#
# Iteration: 458000, Loss 28.133234
#
# Vickdy piraty
# Piressynis skildiack
# Twoma.trows
# Ssiddon
# The munk
# Ginstum
# The s gisowice
#
#
# Iteration: 460000, Loss 28.591650
#
# Ghorn red binsingech
# Toctead
# Metar
# Nodwian
# Doptor ghorggard
# Tagy
# Zolding priggending
#
#
# Iteration: 462000, Loss 28.681522
#
# Juma
# Phegu breden
# Spasce
# Womat
# Zonglonicler
# Jumeet
# The less wilen
#
#
# Iteration: 464000, Loss 27.967807
#
# Spend
# Jomblipter
# Nim
# Girl
# Sexy nwo 8suttabet ghost cor smenle corfirst
# Jonder charmorger
# Ssur
#
#
# Iteration: 466000, Loss 28.772209
#
# Doctor slaper
# Jestic but anicor
# Greabl
# Greek tuck
# Vegune
# Vang
# Gread iterw
#
#
# Iteration: 468000, Loss 28.826432
#
# Jampy bago faviepentey godutamss mack
# Vampispurer
# Sexy sexy velloom
# Japken
# Wighumerluson
# Crafon
# Sampkin
#
#
# Iteration: 470000, Loss 28.185052
#
# Sanic mmipsigge the retart
# Veft vamcie vither tester
# Sexy to s lun wald grumcon
# Jemen
# Thent
# Pherfira
# Poat mo doungs skuth lady
#
#
# Iteration: 472000, Loss 28.576179
#
# Bee
# Zomb
# Herece
# The with balzom
# Woman
# Schoesle must minatidprwo deurher
# Jumph
#
#
# Iteration: 474000, Loss 28.997651
#
# Werkerstulevoy fideradelle dombie cop  fonger
# Moshys ladeinie
# 1990s witch coutyd drumss
# Gidslerlp
# Gragyn
# Modaui saunhwitmengwory
# Co
#
#
# Iteration: 476000, Loss 27.906666
#
# Harkuren anssty tell graid
# Spiderorzean
# Win chagent  chad grady gued queen dalder
# Chuet dinaste spado worl
# Grumpire
# Minssa dactse
# Ceuckly
#
#
# Iteration: 478000, Loss 28.606540
#
# 1012glabry
# Sexy costume
# Tinh
# Walrinker
# T.ed mhavesshit
# Jages
# Batel the scaper
#
#
# Iteration: 480000, Loss 28.856581
#
# Trus
# Purh ghostmana
# Jutriznen
# Bictainuted bobird playone
# 1900s
# Menus
# Strand lang clown
#
#
# Iteration: 482000, Loss 28.362921
#
# Romon
# May invi elsica
# Wxad balletbold
# Dovackinnitchursy hotritha reveict
# Graid bushessor
# Mad
# Sexy bolllashricy nalsosaing
#
#
# Iteration: 484000, Loss 29.336686
#
# Mad prowness dryariana
# Sexy roder
# Zevil che  creng conkri laddr
# Thohe
# Sandow
# Pinom gle
# 00bethus
#
#
# Iteration: 486000, Loss 28.332043
#
# Jonderrirl
# Varl
# Telroo big
# Hanter
# Bee wetra
# Sompuin petranter pirahein gint
# Ginsbue
#
#
# Iteration: 488000, Loss 28.523183
#
# Veviber bearkian girl the ie nup parky ind frons
# The beerton
# Vemon
# Melly
# The munper an smitt frfer
# Pook robot
# Cooth nud wedrwithgald monit
#
#
# Iteration: 490000, Loss 29.032558
#
# Bodetori
# Vacky vislessicleish stratod
# Mard devil
# Wishandizac pooneg horry ninkmon
# Tobers
# The phot
# Sleima
#
#
# Iteration: 492000, Loss 28.585791
#
# Sangeynalm rolhtream
# Minzise
# Zeala orlicy
# Cock
# Sexy cumo slea sor pirand spilaco costumy
# Dr.dog
# Zombatialf reausy
#
#
# Iteration: 494000, Loss 28.952190
#
# Sexy sky girskin
# Raman why0
# Furgit
# Uss emon
# Westbly
# Jund frieker
# Grasiel nactor
#
#
# Iteration: 496000, Loss 29.209431
#
# Heshizal
# Gittle
# Jumple boy calmaubi
# Picae
# Byte
# Berniteta
# Ghanguy
#
#
# Iteration: 498000, Loss 28.513926
#
# Smersor
# Got
# Surize covery
# Surtier
# Vin cinkester
# Zombiroo
# Siojager
# Iteration: 500000, Loss 28.719107
#
# Gother baronde
# Gist
# Thrudry darrins cheellen ticure sharetramo
# Sut  pinkurisebelly fooner
# Worce
# Pemry pinker fola
# Zam truserinongingea
#
#
# Iteration: 502000, Loss 28.703605
#
# Dond falling
# Chashion ganows
# Gwanett
# Pimo
# Path hadza
# Malder cat jace pineen
#  pank rex
#
#
# Iteration: 504000, Loss 28.466445
#
# Thack mariold
# Jomerbothdery trughes man mamgarder
# Maghonkarr corashy
# Crids
# Gadyon
# Maght
# Fizus
#
#
# Iteration: 506000, Loss 28.660031
#
# Tung hission
# Thackay banning zombie percescicirspufmcalerele me
# Preacoe tree
# Sexy with a touggans
# Tibool wrdermes
# Coher apetiirerd chow berdes
# Prinnig 80enchey pires
#
#
# Iteration: 508000, Loss 28.700261
#
# Bog gra dedelic powny
# Sarmas whutie cobe toud alostrel
# Weaver
# Costant melatwos uniens
# Pocs pupes
# Jolar tombick laly potex  fairy queack senakal  ne
# Gilxy puraur
#
#
# Iteration: 510000, Loss 28.293696
#
# Sucoorowingon
# Jack skimbigle hermas
# Liud
# Ffrl
# Spey dog
# Wish
# Qun the roosburg
#
#
# Iteration: 512000, Loss 28.992576
#
# Phongher worper
# Pastan
# Sexy gouss
# Pee
# Trunn eath nandus
# Montorolcar
# Torcage
#
#
# Iteration: 514000, Loss 28.954373
#
# Reentrod
# Zicord pineman
# Witch
# Sulloun
# Teltie taterorn
# Cat
# Mekilostard datene
#
#
# Iteration: 516000, Loss 28.237405
#
# Is lrefim coob scaremor
# Mach of lipria captue
# Spiral devil
# Stiken
# Bstian merry
# Vevil
# Swident of ledi
#
#
# Iteration: 518000, Loss 28.427709
#
# Playian chinn fraw
# Pirgien
# Tean
# Third of sealot quink angel bad
# Pam furm
# Peaton
# Geredeadssin tomby geoss
#
#
# Iteration: 520000, Loss 28.886080
#
# Gli u
# Garrim
# Cho santhtig
# Sqoclicatla
# The gropkerruphom
# Sureke kick op bunch the a dork peftkie metrow
# Pork inrock eri
#
#
# Iteration: 522000, Loss 28.262590
#
# Freddy frank scienty a from oth
# Muddadironkeing decthe of in fave gin
# Prish
# Jelle gurk
# The a queen
# Penst
# Telle
#
#
# Iteration: 524000, Loss 28.668149
#
# Bo am skellar ctcevank
# Carribll
# Partht
# Gill
# Bearley
# Witch
# Zots
#
#
# Iteration: 526000, Loss 28.805034
#
# Part captain queen  hnurs iwlinkerns
# Digpl ent tronst
# Radelincll
# Jomotaun ur ks
# Gyop
# Thestli
# Preat  poxpide
#
#
# Iteration: 528000, Loss 28.492367
#
# Pironangstar
# Piloct
# Zrum
# Preindorg
# Spider
# Slien cll olatmub
# Cliphto mad egdank witch
#
#
# Iteration: 530000, Loss 29.441196
#
# Thelres girly hust the slay tmalegot
# G goml treacron
# Stroflinja
# Badinny the doctor
# The mekgcledeviterleno  lctoo
# Gvir
# The s hele
#
#
# Iteration: 532000, Loss 28.740475
#
# Spiriant ho  fuestmad
# Poodeys mad  cane mady mad
# Coudpy lady frink ath  overy picent wehtodoso
# Witch
# Choke
# Weneo
# Smmakl costle
#
#
# Iteration: 534000, Loss 28.785736
#
# Hason
# Pottane
# Bottigull
# Pead hadda crig
# Fnama
# Penabe
# Waik skunkoggeai
#
#
# Iteration: 536000, Loss 28.909870
#
# Wisp
# Bubbos
# Ducue alaid umfrissc
# Bote
# Ff0t
# Henabs
# Stink
#
#
# Iteration: 538000, Loss 28.553154
#
# Che keasan kenum
# Quonot pengil spotyly
# Zom captain spot of spincasmolasa
# Telle
# Marmef
# Tuppima
# Tell danner henug
#
#
# Iteration: 540000, Loss 28.891266
#
# Madd
# Vemanddic snof sexy citzo
# Megipsker coscure
# Supyerinale cachfikaberma
# 19use
# Vam sienty savey
# Zimps
#
#
# Iteration: 542000, Loss 28.745737
#
# The boy engesexrorhon shoene reshinger
# Jack worhop thi
# Vaider fuion angeg
# Vax cut old
# The marilation
# The the berdamen
# Tophoner
#
#
# Iteration: 544000, Loss 28.278584
#
# Cdellinabro
# Vele
# Turn
# Smizza
# Jantoss hitther
# Eir5se0stee
# Zimen
#
#
# Iteration: 546000, Loss 28.702590
#
# W worhed weray pride merson man
# Mon cat
# Pungatobos the bood ringeng phrandor hottle
# Hipuncot
# Mardatoth the podovante card
# Jutch
# Gleych
#
#
# Iteration: 548000, Loss 28.697698
#
# Zombiam
# 009senare gat
# Jagarme
# Rackmein
# Junter
# Shismer sharky
# Marow yracie mo falk gobumterohe
#
#
# Iteration: 550000, Loss 28.275700
#
# Jumppag the furs teache
# The poine
# Wockunt botteri kinskee
# Vampirent
# Purpiopy mam
# Zoo  dobbie
# Clorf
#
#
# Iteration: 552000, Loss 28.510942
#
# Ja
# Zoutyf trys
# Groach
# Witch
# Ceuscd ssdder
# Hoviss ghost poderdds
# Sstoch l s prink enve nothor peder
#
#
# Iteration: 554000, Loss 28.703575
#
# Homer
# Balle
# Philinog
# Werkla
# Zornasing raho
# Clantioncer
# Buckel aderin moon
#
#
# Iteration: 556000, Loss 28.170652
#
# Heink wilatle sfryar
# Mince
# Mac bagst
# Plfjumt
# Prote
# Nall the in appag
# Jess
#
#
# Iteration: 558000, Loss 28.323648
#
# Shank devily
# Plantighd
# Zeltad
# Gander
# Nocter
# Pentybanfilly
# Fread owtothen
#
#
# Iteration: 560000, Loss 28.912391
#
# Trio drolttarfish spart
# Bog
# Grithitopronesuna quadel
# Schoof
# Marso stown
# Garld scarggliy of sceall scary kim stanth quiludi
# Serecrun
#
#
# Iteration: 562000, Loss 27.828858
#
# Crow
# Laty higlevech4spairy
# The lochoine claced wenti
# The dola mim gihin  qu ctte
# Veepicej 8vysin
# Skice
# Mefs mumper
#
#
# Iteration: 564000, Loss 28.374573
#
# Race thile touct garley burm the bownes
# Muper
# The
# Wingoper
# Wither spems tooster witch badetatiather
# Two
# Cheer
#
#
# Iteration: 566000, Loss 28.705129
#
# 195e captor tirl vag frosholled with grificalesade
# Mink
# Sunfrabus
# Zeon
# Pittege
# Jampire
# Ghost
#
#
# Iteration: 568000, Loss 28.235911
#
# Parze
# Choolegatl dosa
# Pincor man
# Ture ellale
# Pantybuatmins
# Pavi
# Trom wringloor
#
#
# Iteration: 570000, Loss 28.892394
#
# Sexy stwonker
# Greeter the waytantrmov
# Thirg
# Clowsuc
# Thekstan nurt power
# Might
# Winkia beypy
#
#
# Iteration: 572000, Loss 28.440230
#
# Sexy cipeken
# Princoing sand nigg dack elf
# Flalayle
# Princess
# Ghodans pop ball hartuit primes
# Drace
# Toxy
#
#
# Iteration: 574000, Loss 28.276424
#
# Manie mokeman  oobderf shist red
# Pumply wobsher butal mss.ear
# Mongel
# Sexy ruts chazaid
# The chasn oox sat
# Mes
# Polly scool
#
#
# Iteration: 576000, Loss 29.117101
#
# San fleep
# Cat
# Slitscbarinal barenapter
# Ben  anjartor
# Quithel
# Golly school pradong
# Blinceuid reams
#
#
# Iteration: 578000, Loss 28.639433
#
# Coh highesmampantes
# Spidermai
# Sno shirg galsuin
# Roboler holyow
# Vedi
# Ca fromeamy
# Cot r mamp spown
#
#
# Iteration: 580000, Loss 28.611722
#
# Snidardiven and moy herest
# Ved
# Biblerle
# Thitching skigtely jizala
# Jan damella
# Spuft star lias man
# Wizzen
#
#
# Iteration: 582000, Loss 28.754260
#
# Fgincole
# Fleenit
# Twelin nightuc shargic 5othey
# Mantice and horts
# Mpirtice
# Bleaned mad bel t
# Brond in of render
#
#
# Iteration: 584000, Loss 28.429229
#
# Ridcter
# Stwe
# Nedoling fairy
# Toct
# Strise
# Civine
# Zimbows
#
#
# Iteration: 586000, Loss 28.731012
#
# Dutt
# Custer surty maridta widow blue
# Jonk
# Zombie
# Humb
# Ginsan
# Holf
#
#
# Iteration: 588000, Loss 28.798419
#
# Jander
# Mader calc pring cowt premas
# Wenvelf
# Thong clown oy ell madbuster
# Redwenorple
# Zos maughty trejie
# Nemisican camelwirc ffirg slemusiper
#
#
# Iteration: 590000, Loss 28.147266
#
# 0lona dount from sexy vega carmen can racusey sspe
# Spstand rotie cy
# Turder mad evil
# Sexy sexckemanemadoutullunnia fale sper ticemon lu
# Sexy sleop
# Ssgud toar coctin hing
# Teean slundy
#
#
# Iteration: 592000, Loss 28.764740
#
# Pica peanne
# Neng
# Jemandelo and garew band act
# Hennieg
# Poin numer sacol pxenct
# Glinfle ghom loost
# Pilichor poffter
#
#
# Iteration: 594000, Loss 28.717430
#
# Svag an  odor
# Chogger
# Richartie ands
# Momaect
# Sansmantht girl
# Waide
# Wom coato enggus
#
#
# Iteration: 596000, Loss 28.373476
#
# May fhorkoach
# Blucaita princant
# Troog
# Doroliveburefy
# Harr a grucano
# Dlactord horrurbengex fark
# Ghost audenorgis
#
#
# Iteration: 598000, Loss 28.943948
#
# Ghon
# Caral bride hut
# Thenteg
# Thery chie sexy lrosic sowghel
# Rirna
# Zewm burssous
# Scare
#
#
# Iteration: 600000, Loss 29.015066
#
# Tragin berminar.
# Thibor
# Tian
# Gienss
# Mper y rolkail
# Median
# Troosken
#
#
# Iteration: 602000, Loss 28.451556
#
# Pumpko dosch
# Cloypter
# With costle
# D show
# Fcers rarthk
# Hapenna
# Zelly bunner
#
#
# Iteration: 604000, Loss 28.585853
#
# Thite
# Veepl
# Doo sidank the hongy spith grostard bridch mokiobe
# Broche higsror
# Supime
# Weins it
# Wold bad miue dalcon
#
#
# Iteration: 606000, Loss 29.031593
#
# The godberss
# Thet
# Pambuck woldist
# Phorut
# Bok
# Dumpker
# Nelet
#
#
# Iteration: 608000, Loss 28.149266
#
# Drag drll
# Sexy witcon
# The domslecbardee kensarra
# Tumach hoster ruth boos
# Diss
# Drow
# Mad ipskithin
#
#
# Iteration: 610000, Loss 28.766418
#
# Semoroseivilge
# Prge can
# Pan quee
# Pop death waztor
# Sexy igrecing
# Possull
# Plackybse sallic conk
#
#
# Iteration: 612000, Loss 28.947241
#
# Skad
# Werefis puck
# Ceasy king the syby cercon
# Duses ady
# Telepattun eybytien
# Rutel
# Pvedest elk
#
#
# Iteration: 614000, Loss 28.583472
#
# Thin
# Peedorack
# Jandhhals a ulitian panniel pyper oft scama
# Drone
# Velch
# Girlporg
# Juc of worhaksor
#
#
# Iteration: 616000, Loss 29.443606
#
# Quonced fale
# Mitt praynos
# Jostices
# Costles
# Suraketle
# Poice bademon
# Sadged sasta
#
#
# Iteration: 618000, Loss 28.800105
#
# Zombiass
# Dcomis black
# Gim in gree arast
# The lirh ambirt friemoruntigsbare
# Poth photo
# Ban othinorg
# Shoch hogon
# Iteration: 620000, Loss 29.134966
#
# Mursion doctevie creenit mgump ponulsuse
# Mordist
# Lest
# The lowaid in wits older wobestuc
# Pet
# Wizzomors
# 1lunke
#
#
# Iteration: 622000, Loss 29.208486
#
# Pegheri
# Heustrans conk
# Jack s slow ae toop linaurfabe
# Preep
# Jeen spad iragop
# Bot
# Wob
#
#
# Iteration: 624000, Loss 28.828753
#
# The spader
# Clownit
# Weaghiler
# Suicion
# Fhore
# Clacket
# Jeacer
#
#
# Iteration: 626000, Loss 29.113635
#
# Weapedestman poezfientorbax altwiles man
# Flow
# Tolly
# The
# Papoffarger
# Dolyfu
# Teme
#
#
# Iteration: 628000, Loss 29.223361
#
# Juss eretor guns
# Giradce leadler rafperin gire
# Jocker
# Rockira
# Red woay
# Ss. zo lie
# Thinchumina
#
#
# Iteration: 630000, Loss 28.833879
#
# Mydie
# Veacuiticuin
# The the
# Zomo
# Ssoxy oniuls woman
# Mothch
# Vellauze
#
#
# Iteration: 632000, Loss 29.167437
#
# Pather
# The paman
# A skapplk
# Moger  firi shoryhlederdant
# Clom hip poclowerson purgecher ge bost besezeviran
# Terlen in worse
# 10xeper
#
#
# Iteration: 634000, Loss 29.018966
#
# Revie mad
# Punk unca
# Metrea gaten
# Mattet the
# Phutatatt pit
# Sacdpty alocbone
# Jumppin
#
#
# Iteration: 636000, Loss 28.575081
#
# Ziboble mightea cat
# Ggess
# Balmleste harmola
# Stea shelles monstermen sul spashie madamy
# Jam muntoptard
# Skele monstus
# Mon
#
#
# Iteration: 638000, Loss 28.803392
#
# Hoha
# Peg fisppadle
# Scouth nostail
# Cowit
# Ridereler
# Cuttach
# Zekey py stadner nurde
#
#
# Iteration: 640000, Loss 28.645288
#
# Ppily ken tyry scary glount
# Pirato
# Pamptreevonet
# Srion
# Vevil
# Planet
# Zombie
#
#
# Iteration: 642000, Loss 28.642365
#
# Farik a o pingy aphurhstuar tlingle fatih doe dog
#
# Sexy marie ma pillise
# Vinst doflybleberrinin maly
# Hatybuizzinchirppist
# Girl mavyita
# Zim binert
# Hope
#
#
# Iteration: 644000, Loss 29.128924
#
# M rutal bermeriver conner
# Booll
# Mask
# Per kekey
# Wey pask erser bot wonder m robby
# Wey wizi
# Grunch onives
#
#
# Iteration: 646000, Loss 29.139328
#
# 1950rben
# Firsturs
# The slaton
# Banger
# Venster blannees
# Fand yood
# Zomps
#
#
# Iteration: 648000, Loss 28.207839
#
# Scuicat
# The combirostic the girl gill
# Widow toe
# Pombirger
# Dina
# Poashpgon
# Sexy birl
#
#
# Iteration: 650000, Loss 28.805502
#
# Matre and chiemy queere captot
# 00ins
# 10omainc yampight
# Tirxm criphy ruth nacvirial vampiry
# Poca mash magerase
# Pan
# Jaut
#
#
# Iteration: 652000, Loss 29.471709
#
# Ffrirletar parr powal
# Tearr
# Chank pild weof
# Man
# Janks
# Cattevele srapkia litble
# The cat
#
#
# Iteration: 654000, Loss 28.631177
#
# F di
# Piratt witch
# Gurss
# Man indfly
# Elivips
# Zombier
# Jest
#
#
# Iteration: 656000, Loss 29.355849
#
# Wiker
# Tine pleetimoup
# Veno anrermus
# M7increant
# Mr.wits
# Pirane
# Semere hady
#
#
# Iteration: 658000, Loss 29.190107
#
# Potecs
# Jankas on pess
# Nomondna se sejywist addadun jerpaman
# Pacey poom
# Cow ghostreen
# Pows packy dust sonder
# Mailod deven spareens
#
#
# Iteration: 660000, Loss 28.661768
#
# The
# Shader
# Chocpy
# Twrewe
# Marolda
# Wege rereceld
# Vex
#
#
# Iteration: 662000, Loss 29.497979
#
# Batm faloy
# Saven
# 0loot
# Vercer
# Geling orgeroager
# Rlvil uxtarlanghon
# Zombie
#
#
# Iteration: 664000, Loss 28.712623
#
# Weapt
# Jumplagg brenk piratyst
# Thad mad ance sexy adnoypy horre of hintecgan
# From woman
# Thisking fro gandy
# Wirrowelians
# Bottun  harth treyble
#
#
# Iteration: 666000, Loss 28.615482
#
# Debove
# Juedes
# Vean
# Vacddvap gi hoodachipuicer
# Witch gingy
# Gintlumukewribo
# Wergge picy bottreef reanding
#
#
# Iteration: 668000, Loss 28.724690
#
# Carr
# The orveple rocter
# Flampri hood
# Cleic of
# Gordos
# Witch bousk
# Ff7cait
#
#
# Iteration: 670000, Loss 28.470408
#
# Wiza trow
# Thue spnestchunke
# Zombles wazan
# Balch
# Cf yous
# Joh grnekme
# Thutuman
#
#
# Iteration: 672000, Loss 28.653865
#
# Cannarrazora maiuke mad cura of
# Got
# Fosibit
# Mex
# Phiteres
# Milo rabps
# 0ammy
#
#
# Iteration: 674000, Loss 28.885878
#
# The gasso hirsbugh
# Joscus
# Jostus
# Bobors
# Keremo
# Vegald akey s moralon
# Ginsby death
#
#
# Iteration: 676000, Loss 28.159404
#
# Thincesscling girl tooder
# Geet of the bike
# The furgo in eerner blady suff douthe andster
# Jafiel
# Jumper
# Gins demon
# Riniss chailea
#
#
# Iteration: 678000, Loss 28.719055
#
# Pinfrem medna dick
# Mumpetoor jedd rennie princess horssiad
# Jumper ched rexo omsorew goboy poob
# Tardurt
# Heltara
# Gorscory
# Scarlam vowatansbard moch
#
#
# Iteration: 680000, Loss 28.636594
#
# Tiarco
# Graicgemader
# Popks gillcor wolv phe onely batiabo
# Sexy bulmes 500me arsonatoo
# The suayon maskerken
# Gund
# Twrelto
#
#
# Iteration: 682000, Loss 28.168414
#
# Shrey sexy
# Pobaid
# Spaten
# Sexy squiper
# Cooman chuepy from porring bunkens
# Sexy spowne
# Hoptoran
#
#
# Iteration: 684000, Loss 28.467564
#
# Jemose horder
# Pond dien
# Zorg
# Spowal
# Hrifigrer
# Pord petra
# Carecra
#
#
# Iteration: 686000, Loss 28.926614
#
# Will
# Ul sevelieton
# Batielly barlersherga inginethelrin rat bancernand
# Fredadanne
# Ce pandy fillurce ontchay pumpkit
# Jeadul
# Jantog affirloro
#
#
# Iteration: 688000, Loss 28.206027
#
# Turg
# Dounccice
# Pote
# Jesom
# Ghost
# Rana
# Scipher
#
#
# Iteration: 690000, Loss 28.427829
#
# Garth flori
# Ghose
# Sexy pilay
# Fred muent pypesete
# The porfficce hibsber
# Nomund
# Pffie bi
#
#
# Iteration: 692000, Loss 28.825922
#
# Tersorterre
# Zip blacts
# Scat
# Karm dess
# Vands retet
# Wander
# Gow dim bambun pencter
#
#
# Iteration: 694000, Loss 27.887362
#
# Boll
# Kelicer gof bothgly the vampion
# Vomsser
# The card
# 0widn
# Zerelle cheen mendle
# Sexy rorky sina
#
#
# Iteration: 696000, Loss 28.375668
#
# Sharlarill cacits
# Cam
# F grist
# Neinnose murto
# Punke judn
# Wain ony racm
# Wfrobo tartor preain
#
#
# Iteration: 698000, Loss 28.646534
#
# Thetme
# Vely  fighty ling in night print tcemos snidcess a
# Naster
# Thinges
# The pacait
# N8ma with pripon brifes stiter
# Zar frimssus
#
#
# Iteration: 700000, Loss 28.501305
#
# Girll an pageil  indelibald
# Thll inter
# Mall sexy
# Tht nun
# Sam rexy aman cuketh scatur pastale nubo ninny
# Gorase
# Paghealf in too man
#
#
# Iteration: 702000, Loss 29.007905
#
# Bot wrapeln
# Header ann
# Fate of in prince
# Turdion
# Ghoc snacear
# Neb mustil ny of doctirpleneyboy kimetabre zomball
# Minaurl nester
#
#
# Iteration: 704000, Loss 28.386627
#
# Sexy godin sexy ar
# Blockin ruby robot
# Butm
# Ponga 5000l factorth
# Nioglatinkine
# Cheeth
# Pirate
#
#
# Iteration: 706000, Loss 28.476464
#
# Parite
# Jolator  ain
# The cof
# Coctorat
# Snaldente
# Pore
# Skunamsina digladet
#
#
# Iteration: 708000, Loss 28.972589
#
# Van bale mots sexy wad bhers briffar
# Vickles
# Grantarde
# Prink speate
# Vin sorks orman
# Je
# Costuts
#
#
# Iteration: 710000, Loss 28.724787
#
# Wigher monster
# Teleseder grell plinch
# Mampad pingurgince hark
# Mbailobart barey angacl eypuie
# R2wert
# Drons
# Vennedduman red peasima and ca jalion
#
#
# Iteration: 712000, Loss 28.820577
#
# Devin orawbacle
# Zomblme exsters
# Coscuw
# Sleveablewern mimerams
# Fretthers
# Choy cowbag
# Toy
#
#
# Iteration: 714000, Loss 28.542946
#
# Charman
# Thoun
# Maguls
# Noatati onesite
# Tortist
# Fe pippe
# Turse
#
#
# Iteration: 716000, Loss 28.571775
#
# Zomberf winkle
# Po
# Vampire sudy bame
# 19verlats spink
# Ny
# Phuts
# Jussionkin prayon
#
#
# Iteration: 718000, Loss 28.824516
#
# Throckled user
# Vamich  ff clevilbist
# Qoons
# Thably busta
# 097elfran
# Bottpunt
# Mhank
#
#
# Iteration: 720000, Loss 28.580184
#
# 0ouncter
# Freaco
# Hadostmer
# Panese
# 1950stler pradernessod sliberelay hare jana
# Pott creat leenig
# Vex hrides
#
#
# Iteration: 722000, Loss 28.250232
#
# Vamm offha of tleal ninikar och
# Rontoll memimmy
# The dam cow
# 19olk
# Conato
# Tha thile
# Laht tudi the gea
#
#
# ...
# Zoman
#
#
# Iteration: 760000, Loss 28.817309
#
# Thun
# Remton
# Joen
# Pippers
# Jaid
# Trugh
# Jumter a noe blatiog
#
#
# Iteration: 762000, Loss 28.419384
#
# Mister hordabey inetch
# Stote
# Boms owesd boterflo firibes
# Chep praper
# The ma evet
# Sardice butte
# Mime
#
#
# Iteration: 764000, Loss 28.635723
#
# Perse
# Demos chewinan cheffstuck
# Ching hilly
# Coun il villy ow punner horras monter
# Sexy
# Pumpk
# Duso
#
#
# Iteration: 766000, Loss 28.568235
#
# Dr. hyr stevetor
# Tholeg ongon
# Greldert of chinda
# Tho cleppyien a geampin doctor
# Mall
# 0rampira
# Drageever
#
#
# Iteration: 768000, Loss 28.047661
#
# Weenata porton
# Zimanteyachejarte falan
# Jars cerad
# Minhy bat
# Poopy
# 1980bigs gap
# Chally
#
#
# Iteration: 770000, Loss 28.345912
#
# Weavion player
# Jedil ampira
# 16umpiwatting
# The maskait
# Cat
# Trigh surkst
# Thinging amach higruto
#
#
# Iteration: 772000, Loss 28.939875
#
# The
# Zost goth s wombi
# Monsbie
# Combal teaper
# Zan
# Jrurtoklighonimumpine
# Dosttos
#
#
# Iteration: 774000, Loss 28.740589
#
# Thel
# Vit
# Velspire ninja derralfawhe piravalf checther
# Tardot
# Wald hispuffs darthre hocartyt yann harewhoad
# Bluen fathorpcalfalluet
# Vextian pider statte sexy chusper
#
#
# Iteration: 776000, Loss 28.675730
#
# Pom wacker
# Ward whasian
# Vermer
# Wrald mcelle
# Slayeban
# Dog llf
# Cow sheepsa oriber
#
#
# Iteration: 778000, Loss 29.019785
#
# Vevillus ginger
# Rout
# Gigpy
# Redy badins
# Jop kotr boy
# Slumbly kwi
# 17sil shard revag
#
#
# Iteration: 780000, Loss 28.045022
#
# Charry jumpkisan doll
# 1950 in
# Monstresc and wond wome
# Marry
# Veter
# Lorser
# Plock bat
#
#
# Iteration: 782000, Loss 28.388872
#
# Cly
# Chiom leldosal ball ghoslhel
# Mybirt shirste
# Veke
# Mwickac dut
# Scattiell wizall bead
# Sexy gop mmetice mariry
#
#
# Iteration: 784000, Loss 28.955265
#
# Gistm
# Velterdate man
# Gr2m ming
# Whine amulam
# Garlliol fishum gendcerery
# Py garer
# Pumpkeenoner
#
#
# Iteration: 786000, Loss 28.181476
#
# Piratsu
# Donkeng
# Wens
# Rapa inckis of the piever sandy
# Sexy procton
# Janted badesey of clinbeker girl
# Drack
#
#
# Iteration: 788000, Loss 28.945312
#
# Deve
# Werstumbs
# Womtizar
# Peg
# Turbuit
# Frot
# Jpertot cochin loss with villy
#
#
# Iteration: 790000, Loss 28.805738
#
# Girl
# Cloerist
# Monasy
# Roteychusher brhars
# Mell
# Zant rasypeatch
# Ghonin
#
#
# Iteration: 792000, Loss 28.512123
#
# Pagto
# Souy
# Ceto jaky n
# Jarso ninjam
# Vaser
# Dal  frice lawktei
# Roboanger poe
#
#
# Iteration: 794000, Loss 29.159132
#
# The wold
# Jaerin sexy ans
# Jom harl  hat
# Veltarox
# Jugm burs nee gowil liot hot
# Ghost drlabread in pee the quiene jampu lobhz hte
#
# Hearder germa
#
#
# Iteration: 796000, Loss 28.650400
#
# Mintleana
# Budered kllaly
# Tuld autys
# Wians
# Zudhal
# Wlubror sbameris
# Jome trurd
#
#
# Iteration: 798000, Loss 28.463247
#
# Cabrew crow  vonalan cthtch
# Past
# Dryan ofrspurd oanit a gann and in purkle
# Bbder
# Rumed comblivile viglorgja
# Jelbat
# Dessaverlial
#
#
# Iteration: 800000, Loss 28.787836
#
# Spaws lagton
# Dapedo
# Diech
# Teller
# Weapie pood witco
# Dish
# Dead floeriri
#
#
# Iteration: 802000, Loss 28.584442
#
# Pelping touna the hald mar wandy friesbaht
# Drochy pinans
# Zom ne pevit  hie traine
# Zombll bapumen
# Wigpsys galle
# Tuw
# Zilokian
#
#
# Iteration: 804000, Loss 28.836465
#
# Man a skikers
# Ekaper sspivey buckevsmid
# Mighos
# Pug viker turla
# Morifrettrawz
# Mitt
# Mydrict
#
#
# Iteration: 806000, Loss 28.898566
#
# Rutwh  addom mampiun
# Darthtaurclup
# Drestude
# Plankume
# Jack l wonard
# Drostuld player
# Aloats
#
#
# Iteration: 808000, Loss 28.397875
#
# Thrinnit
# Reffice
# Just
# Gimas
# Ho
# Thesmikirlft
# Phushit egter
#
#
# Iteration: 810000, Loss 29.021465
#
# Fronsceonk
# Ghomuce gailla powarey princy curserie
# Pumph
# Gredil cockey hardy laxe rata
# Pangsor
# Potentess
# Rack ondeed ree cat
#
#
# Iteration: 812000, Loss 29.091612
#
# Rosn
# Doat girl in pampunch
# Bat
# Tablmptin redea
# Zaim latul
# Jemie
# Merphaer
#
#
# Iteration: 814000, Loss 28.454771
#
# Sexy soodle suma
# 8 gir
# Ging babt
# Jan in ppit
# Cule mario neeth
# Ran sexy gial
# Welet
#
#
# Iteration: 816000, Loss 29.147705
#
# Dupdar chilbberle prinlerbder ronia dersost frode
# D puiteng bustrsail madrarmairane
# Frigper compiinsal soritul katul dactae hust ftear
# Marm
# Portett brossy punk vinam stawea docker chiun eack
# Dear
# Trag
#
#
# Iteration: 818000, Loss 29.287931
#
# Gorstor
# Jog scerery
# Permess
# Vamplabers
# Pormet
# 192ller
# Pecthome
#
#
# Iteration: 820000, Loss 28.745930
#
# 19vems branpetr
# Gomen
# Sexyer witur
# Bex frrese ich
# The
# Guey
# Jcant
#
#
# Iteration: 822000, Loss 29.212433
#
# Sand oow
# Frock eizhtynapas
# Sexy slayered
# Scov
# The hisuik butpe old bowreadniss
# Gi a harem
# Zevin sweeniack clakenth hosailun
#
#
# Iteration: 824000, Loss 29.360148
#
# Racke studer boo
# Rgisex the ycoss
# Tra
# Vell
# Sciremas
# Gillread
# Fulins
#
#
# Iteration: 826000, Loss 28.120368
#
# Dolake wifle swurg mante doctialf killyn
# Botth  butni
# Vammarm arder
# 1ahertor sexy masiooburgchi looby
# Vex
# Sexy
# Ponk the kimgie the prutraw
#
#
# Iteration: 828000, Loss 28.553795
#
# The incher
# Douder
# The ovemed
# The hocke suit
# Pettrug
# Dabohewhipryte
# Mozery wirgider the sexy
#
#
# Iteration: 830000, Loss 28.790653
#
# Draper
# The garzy mongen uetcpcout
# Shincos
# The pan
# Women drgo
# Ggensfy bue s
# Pumnting ruten eichty hofa
#
#
# Iteration: 832000, Loss 28.466076
#
# Babun
# Moon
# Cheed dive
# Prund
# Dock rase
# Pliper
# Weess
#
#
# Iteration: 834000, Loss 29.321257
#
# Sund leyglebt j.lsbare hadarg
# Sffseme prither
# Charlle holy
# Than
# Rangong lilid getress
# Rectorats ar
# Gram red roster
#
#
# Iteration: 836000, Loss 28.545833
#
# Medow
# Carrokele arsepie
# Jeer clobl in berman
# Jurry hat
# Hobosill
# 80ira
# Maskuiey houre
#
#
# Iteration: 838000, Loss 28.664168
#
# Mimbie halume coastit
# Stonkinoward dayet
# Cheenge leingettherame
# The manable rine arira
# Thookey
# Pooddan
# Thing fosham fim man
#
#
# Iteration: 840000, Loss 29.328243
#
# The barl mam
# Catryra
# Mastego  hok
# The
# Med redosa
# Mastik trescun stelly ginds dambean mickle
# Sstung
#
#
# Iteration: 842000, Loss 28.984850
#
# Berfer
# Zorkian
# Dramed a sailon andea dancor
# Grugkry godder
# Peninsachd one indieh sailinas
# Bladecerialbdaseagidsbo
# Weavine
#
#
# Iteration: 844000, Loss 28.709188
#
# Piriflle
# The bavine
# Rutce
# 19x anoan
# Cow
# Voddracol
# Bott
#
#
# Iteration: 846000, Loss 28.940671
#
# Georoles mumtatrir gruttern
# Bick from agstegeg
# Sund bead
# The saversdal ginn urn fisherilmar heamperman the
# Walket
# Mesher
# Jach
#
#
# Iteration: 848000, Loss 28.427002
#
# Mbobardinger
# Jim pin cashpla
# Pop
# The raticroson picer caned perk
# Sooticapher
# Phetle pefficeder
# Jeen lactwarlice
#
#
# Iteration: 850000, Loss 28.739076
#
# Harri
# Jatubl
# Jebbockea
# Pee turginsiceroma
# Ballow wendman
# Fisie bride
# Jog
#
#
# Iteration: 852000, Loss 28.536467
#
# Pen a beer piller care omilory revers spac mescist
# Pimbie
# Jongeduico
# 19vegine pimales
# Dferm
# Beal hress coughmar
# Snennyble wascoring
#
#
# Iteration: 854000, Loss 28.190605
#
# Sinaki
# Reath captherema the wim pridsly
# Perse of deathrele chaet
# The ravecher
# Vembe fie rot fuilla
# Gacuet offurbert
# Thobertentaurit
#
#
# Iteration: 856000, Loss 28.636235
#
# Leeny bypoctor huttherweeno
# Mp a hilloan the hank
# T.bleer
# The guil
# Raccortore malan of red sters poonthumbler
# Rigce
# Coomes
#
#
# Iteration: 858000, Loss 28.682870
#
# Ginch
# Pen sheothe powarr
# The moo low lig
# Gans hockprwie ang
# Latina giraf batcor
# Watul
# Pippug
#
#
# Iteration: 860000, Loss 28.477398
#
# Wol wele
# Zoman
# Sexy herswi jute tardisicolfer
# Vam wands
# Werantosisok
# Table
# Mackey
#
#
# Iteration: 862000, Loss 28.932612
#
# Sadoot
# Rayen
# Vall
# Woman
# Pandosh  sed binle
# Jock flutter malkers nurse
# Folad
#
#
# Iteration: 864000, Loss 29.133547
#
# Jowbest
# Seve pirmeriar
# Dicky
# Bom ie yine
# Dondioun
# Bollead gralle dragot quark
# Velner
# Iteration: 866000, Loss 28.375023
#
# Plhiack kentirl
# Naptist
# Pampion ilovensha
# Thatlesbie wimokaik fary
# Proctsstore gistin
# Playor
# Zin
#
#
# Iteration: 868000, Loss 28.221511
#
# Poor
# 8 sexy grom r ward
# Shiher ampion
# Reveld car witco proda
# 19cah pank lllenerd carchgoon womby fal swoldsha s
# Vamburd girl booda
# Pirate
#
#
# Iteration: 870000, Loss 28.853734
#
# Pimal striet
# Mamader
# Hoods kith catewerey ssuprevirepus cattor a unbi
# Jau garr
# Caurt
# Duper
# Corter fuiters  frie engel sharl me
#
#
# Iteration: 872000, Loss 28.259017
#
# Vex
# Slugusbus
# Frildishnacor
# Bo
# 19cer
# Truth
# Mam morsence
#
#
# Iteration: 874000, Loss 28.698203
#
# Blana herirgit
# Peait
# Princess
# Pweerfpemenianda
# Speermlus
# Deak teap
# 10asone
#
#
# Iteration: 876000, Loss 28.510067
#
# Moonh
# Bat card ofwim
# Buechake
# Fiply
# Jaim
# Pack dist witchures stew
# Ghost
#
#
# Iteration: 878000, Loss 28.432056
#
# Miss hongoner
# Zhatcadonis
# Dov
# Placounskoot
# The toco nighter
# Dog
# Tira
#
#
# Iteration: 880000, Loss 29.355438
#
# Jembla tericelibard lets
# She ly mamad
# Zel che
# Celette
# Bustlent the calk
# The leblalon
# Got
#
#
# Iteration: 882000, Loss 28.613490
#
# Hrignose swhalt
# Ratt
# Pumpkin
# Jcatder
# Po
# Pitsting
# Ff7padobble
#
#
# Iteration: 884000, Loss 28.526751
#
# Veby spideruor
# 198fles
# Zombie s snister
# Chienetej
# Mampirakes
# Zlentlus dle sexy mankirs clayen order
# Dale ddo timonarde
#
#
# Iteration: 886000, Loss 28.634250
#
# The doctee
# The man
# 8or
# The of telle
# Boad
# The t greetlereavi  flayer
# Bunas sexer
#
#
# Iteration: 888000, Loss 28.485660
#
# The hutburge
# Tress geledme hut
# Jaly
# Cosced pole hertaty tomble hostata
# The dibuck off
# Freepadree
# Peyolt infly littot witch potakes hamburty nercer
#
#
# Iteration: 890000, Loss 28.652410
#
# Namble nater ninja
# Pidssing
# Grincess
# Ghangining armid frien ivel qkibumen
# Dugharlemalk bar
# Sarriub
# Marriving aumex bedreg
#
#
# Iteration: 892000, Loss 29.164828
#
# Dred and cascand fingic andiretule cat finnsman
# Thar
# Pintia
# Jan einan
# Dock
# Cut
# Plangursseatfiine
#
#
# Iteration: 894000, Loss 28.595180
#
# Gharitema hine
# Griem blather
# Wainic
# Ghim aluing
# Sklot
# Woun
# Cattance
#
#
# Iteration: 896000, Loss 29.130723
#
# Spey um ratwette
# Veg dn5chickege
# Sicer
# Zarar
# Jataal
# Sexy pumpking
# Phapkil oa mankenger ghosck
#
#
# Iteration: 898000, Loss 29.026177
#
# Witber nurker woug
# Bat
# Gill
# Janster
# The sulle jow
# Skuller
# Bosti
#
#
# Iteration: 900000, Loss 28.365090
#
# Cheen of goth
# Bin
# Wllar
# Zlinges
# Bulminen a the rumagy
# Cats costain
# Boant
#
#
# Iteration: 902000, Loss 28.729266
#
# Sheen a pome indfabe tst coimass
# Jes woman clork
# Pun
# Vest of hifigjaning in
# Dritt
# Suremon the andery th
# The sexy cat
#
#
# Iteration: 904000, Loss 29.515740
#
# Bopuis
# Vit
# Bumare rates
# Colesad prins
# Bumburk
# Chan camplit petim sounic untred tanciargiblin pre
# Rirkul pikad dralle bomburpi
#
#
# Iteration: 906000, Loss 28.969076
#
# We ovneh flaicion than
# Torfffiscebad anidd donat
# Lamwis clizher
# Thewn
# List tonton
# Thowis
# Jasky
#
#
# Iteration: 908000, Loss 28.865986
#
# Pumatene udtant
# S wander
# Madhe pilato
# Sperdethet
# Gilla
# Slare
# Ganiond
#
#
# Iteration: 910000, Loss 29.360495
#
# Co diso hunned s rapa dict sinja low snowk skffish
# M7s
# Ghost
# The ti
# Cipns
# Chroge
# Tyist  isted stelin the peablon
#
#
# Iteration: 912000, Loss 28.125357
#
# Zendeld mampure
# Pudeld of evidin quipper
# Zem
# Vaman
# Pan
# Zoman
# 8us pirath hada of sexy lio drgsatide
#
#
# Iteration: 914000, Loss 28.583739
#
# Thist
# Ghosber
# Zens
# Worder spidpel
# Trlosor jeltherman capper
# Pots girer spleane
# Tung in penger
#
#
# Iteration: 916000, Loss 28.887341
#
# Baremas
# Ghost
# 19umpen
# Chacel
# Dysb
# Radie
# Smxygesty cabant
#
#
# Iteration: 918000, Loss 28.498894
#
# Telen
# Speaper
# Monh eltorl
# With voopkin scie cow
# 1ome tamu man
# Tarsuman
# Ddmelmact
#
#
# Iteration: 920000, Loss 29.057804
#
# Wly
# Ghart
# Dien
# The arthans
# Diud mentey elbot
# Greadimar
# Powgcore
#
#
# Iteration: 922000, Loss 28.842459
#
# Jutard
# Vandherna ms. pects lemer
# Collsaereinoghrinstnicarry godder girattesse.
# Blad pench jaurs the se cutter
# Pang ratza coso
# Vampire wizarder ginsboyer
# Jullur
#
#
# Iteration: 924000, Loss 28.766482
#
# Patass harsh wirsandme
# Pendie
# Masky 809war
# Pip dan cant a spatine
# 0900rovin minem roth tstowole deston clood
# The baple bronices
# 1ase
#
#
# Iteration: 926000, Loss 29.534452
#
# Comery pactorandbermer
# Nvinais
# M beg
# Mas
# Fantona
# Boldcy blocker
# Wnesson lotie nom cals pedper
#
#
# Iteration: 928000, Loss 28.979897
#
# Sexck
# Gstlesturirber
# Telraheribaselpy
# Quryy
# Tulbat
# Vallos
# Foosimax
#
#
# Iteration: 930000, Loss 28.824052
#
# The sexy letol masp
# Murise
# Sexy cispan dutablll
# Vamo
# 19mypabottise
# Beathts
# Patalesea
#
#
# Iteration: 932000, Loss 29.703120
#
# Ghost
# Mantul of of
# Watress
# Chizzot
# Man
# Manttal kessigattiar preic marl
# Grey erriro
#
#
# Iteration: 934000, Loss 29.000067
#
# Torte
# Worse cerus
# Ghgin
# Gaterb buge
# Gridy
# Got
# Veepo axy maumanie oock
#
#
# Iteration: 936000, Loss 29.220477
#
# Clowrich wergon
# Pouspler
# Neble kwiler
# Vavit
# Dost chestermen
# Phegect
# Phing
#
#
# Iteration: 938000, Loss 29.196100
#
# Facratang deader the loshbeda
# Devienth
# Meginy jag
# Thlerman
# Pelfing hormaum deun
# Vench
# Musts
#
#
# Iteration: 940000, Loss 28.696580
#
# Xalicorm
# Threa ongro purere
# Speen nobotck hurtone
# Comss
# Bokinging squobamy
# Ffauriculfrino
# Pus
#
#
# Iteration: 942000, Loss 29.373763
#
# Gist
# The fin
# My flinatetna ted red
# G red rot
# Player
# Gulffysitata
# Porger
#
#
# Iteration: 944000, Loss 29.073841
#
# Finta
# Powie irlui picarr nuthd
# Veattod nieverma an us rarsenam bag gif ginster
# Chating atter busk
# Woman
# Doser
# Zombuta
#
#
# Iteration: 946000, Loss 28.559338
#
# Thrios
# Roby cout
# Bobunal pirate
# Spaicesslumps
# Jam bridescuge tan
# Cust
# Po irans
#
#
# Iteration: 948000, Loss 29.160780
#
# Fiu
# Morschiche
# Rodenion anquastra
# Box
# Pwingegda
# Gat burn
# Lostat.te myerderee
#
#
# Iteration: 950000, Loss 29.283054
#
# Grason
# Vacherus
# Gotter
# Jfainuburmugriath
# 2chan
# The hockler vampirancen
# Franka arbyod trunste
#
#
# Iteration: 952000, Loss 28.556361
#
# Capthis best
# Schowereeoct
# 198dy
# W w thockdy the fagtle
# Witll the why
# Pida ff buble phellya ruzle ninjlegent factor
# Clincess
#
#
# Iteration: 954000, Loss 28.887608
#
# Mhatt foars berrion
# Numblecla bast
# The swalbait
# Pait offral pikinarth mik rubice bestandbabegirl
# Prom
# Patab and
# Jlung
#
#
# Iteration: 956000, Loss 29.406844
#
# Qarech fall cocperunt
# Je
# Moden deadba bunns stannardst
# Trout min
# Boss coocenasde
# Poralod melss bad
# Modster
#
#
# Iteration: 958000, Loss 28.511022
#
# Grapeachetronant
# Zowthroneena
# Woman
# Vimp
# Ny from blocker lackky beack
# Dyar
# Greentrog
#
#
# Iteration: 960000, Loss 28.813262
#
# Fish
# Sexy ster arillant
# Whink
# Floust
# Woman
# Mam
# Zoman
#
#
# Iteration: 962000, Loss 29.164961
#
# Gaster weing
# Zoprraga
# Pizal man
# Teait
# Nonder kinne badaper
# Pob
# Frangbess woids
#
#
# Iteration: 964000, Loss 29.337101
#
# Wover nurs princy montcie
# Talqu1br
# 8900s cuerow
# Ene
# Cyptir cape
# Wintie wof catar tobus
# Ree winkerlie girsimek
#
#
# Iteration: 966000, Loss 30.050127
#
# Stack
# Shoc ooff
# Zaper robol captaicy man
# Girl
# Gandsuse
# Bopsaiow
# Sexy norbe scouses
#
#
# Iteration: 968000, Loss 29.114761
#
# Morsber
# Giall
# Ginsbrey beang
# Suawe
# Clampsiet
# Homan
# Pemmar beas
#
#
# Iteration: 970000, Loss 29.198289
#
# Mirthte cat
# 000scedt
# Pasca
# Perg mmusslar pledu xeythanss
# Pn9charn vevilablen
# In bead
# Sperancht
#
#
# Iteration: 972000, Loss 29.879068
#
# Printas berdist
# Trunker
# Vetron sshinjhy gottiotl
# Bridt
# Sicinciakstut
# Hoort
# Tal withyes
#
#
# Iteration: 974000, Loss 30.005242
#
# Pincene
# Portorak
# Wstua ce jeena
# Gobaid lanedowperman kilboa squitted
# M clieso priphd maugain
# Durgirera ghosbua
# Gued gumlluzel
#
#
# Iteration: 976000, Loss 29.926726
#
# Ppopkina
# Corkter
# Vask
# Werary
# Prinners
# Ty chotaldy frredout friflit
# Scho
#
#
# Iteration: 978000, Loss 30.444288
#
# Guddolo binger
# Godist
# Wichrignic horlen
# Pryaly
# Datric worn flajer pla prader
# Wing a tadom
# Gible
#
#
# Iteration: 980000, Loss 29.855382
#
# The bat courtermay man
# Gotbeaumbled modus
# Truppue defbers handnard
# 0reinale ghost rondass twingrr dardain peinery gar
# Ger plan
# Zomil chist in bomas
# The
#
#
# Iteration: 982000, Loss 30.572716
#
# Joke
# Pole
# Dow
# Gie
# Courge
# Peobet
# Blode ginsburg
#
#
# Iteration: 984000, Loss 30.440841
#
# Pien
# Ute pacompireniag phoum thgen
# Docenlial
# Vefy fain the snishing hirt
# Zomse
# Thl
# Ghisk
#
#
# Iteration: 986000, Loss 29.953028
#
# Gholly scomon
# Drunk sexgon gofy carffooun luntell s
# Deb
# Bhentesage helrpy marie magister
# Mharcl ale
# Besmn areradobobaremanerd enunaid minean of stench
# Wid manfanleba
#
#
# Iteration: 988000, Loss 30.145865
#
# Greacion
# Guxh
# Gusada
# Pinemastard an1wink
# D pumpistra
# Zonglambaster
# G1rem freard
#
#
# Iteration: 990000, Loss 30.342019
#
# Coredr kmpricy moon
# Morr
# Witwon
# Spidy masofy
# Wipllinerin
# T wonciscat
# Wuigh man
# Iteration: 992000, Loss 31.177742
#
# Witcla pudch jaston
# Giobbat
# Gandse tat
# Didinnit lray ardet hiin isesry wrichsifacs
# Sexy porach sexlice stody
# Zo peffis pigy jakie piking
# Gint goon
#
#
# Iteration: 994000, Loss 33.035770
#
# Dor mpi cobistirl
# Jowaber
# 1aru
# Zestwlester
# Gindeantcor
# Poniskyar
# Zarshut orow
#
#
# Iteration: 996000, Loss 35.463218
#
# Qhop
# Doxs
# Thed pelst ieced gogmstr tibar opiccmiichat.ffina
#
# Fats
# Wnons bimlon aridcud cicersushgwina ared eustred d
# Guc typyofdead chow r vany2sawie doaporet r2tista
# Par
#
#
# Iteration: 998000, Loss 37.268053
#
# Joeveot leoe actoyhqer gexs
# Rodete
# Wueand eiatgexyddinerssdapereruywe ceresapcyernzod
# Wichreboti
# Qir
# Wioschen
# Ver
